# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import cv2
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Pre processing

# %% [markdown]
# #### Đọc data vào từ folder

# %%
def load_images_and_labels(df, root_path, target_size=(224,224)):
    images = []
    labels = []

    if not root_path.endswith('/'):
        root_path += '/'

    for idx, row in df.iterrows():
        image_path = os.path.join(root_path, row['crop_face_file_path'])

        print(f"Processing image {idx + 1}: {image_path}")

        # Check if image exists
        if not os.path.exists(image_path):
            print(f"Warning: Image {image_path} not found.")
            continue

        image = cv2.imread(image_path)

        # If image couldn't be loaded, skip it
        if image is None:
            print(f"Warning: Failed to load image {image_path}.")
            continue

        image = cv2.resize(image, target_size)  # Resize image to a standard size (224x224)

        images.append(image)

        # Convert multi-label to a list
        label = [row['natural'], row['sleepy_eye'], row['yawn'], row['rub_eye'], row['look_away']]
        labels.append(label)

    images = np.array(images, dtype=np.float32) # Chuyển sang float để chuẩn hóa sau
    labels = np.array(labels)
    return images, labels

# %%
# Path to CSV file (adjust to your machine's path)
csv_path = r'/content/drive/MyDrive/ComputerVision/dataset_multi_label/training_data.csv'
df = pd.read_csv(csv_path)

# %%
print(df.head())
print(f'Số mẫu: {df.shape[0]}')
print(f'Số cột: {df.shape[1]}')
# Out:
#                original_file_path                    crop_face_file_path  \
# 0  images/20250307_222829_001.jpg  cropped_faces/20250307_222829_001.jpg
# 1  images/20250307_222829_002.jpg  cropped_faces/20250307_222829_002.jpg
# 2  images/20250307_222829_003.jpg  cropped_faces/20250307_222829_003.jpg
# 3  images/20250307_222829_004.jpg  cropped_faces/20250307_222829_004.jpg
# 4  images/20250307_222829_005.jpg  cropped_faces/20250307_222829_005.jpg
#
#        labels  natural  sleepy_eye  yawn  rub_eye  look_away
# 0     natural        1           0     0        0          0
# 1     natural        1           0     0        0          0
# 2     natural        1           0     0        0          0
# 3  sleepy_eye        0           1     0        0          0
# 4  sleepy_eye        0           1     0        0          0
# Số mẫu: 3436
# Số cột: 8

# %% [markdown]
# #### Đọc image, labels vào từ folder (chỉ load lần đầu khi chưa save images, labels)

# %%
root_path = '/content/drive/MyDrive/ComputerVision/dataset_multi_label/'
images, labels = load_images_and_labels(df, root_path)
# Out:
# Processing image 1: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_001.jpg
# Processing image 2: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_002.jpg
# Processing image 3: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_003.jpg
# Processing image 4: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_004.jpg
# Processing image 5: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_005.jpg
# Processing image 6: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_006.jpg
# Processing image 7: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_007.jpg
# Processing image 8: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_008.jpg
# Processing image 9: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_009.jpg
# Processing image 10: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_010.jpg
# Processing image 11: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_011.jpg
# Processing image 12: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_012.jpg
# Processing image 13: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_013.jpg
# Processing image 14: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_014.jpg
# Processing image 15: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_015.jpg
# Processing image 16: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_016.jpg
# Processing image 17: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_017.jpg
# Processing image 18: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_018.jpg
# Processing image 19: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_019.jpg
# Processing image 20: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_020.jpg
# Processing image 21: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_024.jpg
# Processing image 22: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_025.jpg
# Processing image 23: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_026.jpg
# Processing image 24: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_027.jpg
# Processing image 25: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_028.jpg
# Processing image 26: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_029.jpg
# Processing image 27: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_030.jpg
# Processing image 28: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_031.jpg
# Processing image 29: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_032.jpg
# Processing image 30: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_033.jpg
# Processing image 31: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_034.jpg
# Processing image 32: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_035.jpg
# Processing image 33: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_036.jpg
# Processing image 34: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_037.jpg
# Processing image 35: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_038.jpg
# Processing image 36: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_039.jpg
# Processing image 37: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_040.jpg
# Processing image 38: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_041.jpg
# Processing image 39: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_042.jpg
# Processing image 40: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_043.jpg
# Processing image 41: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_044.jpg
# Processing image 42: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_045.jpg
# Processing image 43: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_046.jpg
# Processing image 44: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_047.jpg
# Processing image 45: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_048.jpg
# Processing image 46: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_049.jpg
# Processing image 47: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_050.jpg
# Processing image 48: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_051.jpg
# Processing image 49: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_052.jpg
# Processing image 50: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_053.jpg
# Processing image 51: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_054.jpg
# Processing image 52: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_055.jpg
# Processing image 53: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_056.jpg
# Processing image 54: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_057.jpg
# Processing image 55: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_058.jpg
# Processing image 56: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_059.jpg
# Processing image 57: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_060.jpg
# Processing image 58: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_061.jpg
# Processing image 59: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_062.jpg
# Processing image 60: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_069.jpg
# Processing image 61: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_070.jpg
# Processing image 62: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_071.jpg
# Processing image 63: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_072.jpg
# Processing image 64: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_073.jpg
# Processing image 65: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_074.jpg
# Processing image 66: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_075.jpg
# Processing image 67: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_076.jpg
# Processing image 68: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_077.jpg
# Processing image 69: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_078.jpg
# Processing image 70: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_079.jpg
# Processing image 71: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_080.jpg
# Processing image 72: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_081.jpg
# Processing image 73: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_082.jpg
# Processing image 74: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_083.jpg
# Processing image 75: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_084.jpg
# Processing image 76: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_085.jpg
# Processing image 77: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_086.jpg
# Processing image 78: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_087.jpg
# Processing image 79: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_088.jpg
# Processing image 80: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_089.jpg
# Processing image 81: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_090.jpg
# Processing image 82: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_091.jpg
# Processing image 83: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_092.jpg
# Processing image 84: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_093.jpg
# Processing image 85: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_094.jpg
# Processing image 86: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_095.jpg
# Processing image 87: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_094.jpg
# Processing image 88: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_095.jpg
# Processing image 89: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_096.jpg
# Processing image 90: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_097.jpg
# Processing image 91: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_098.jpg
# Processing image 92: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_099.jpg
# Processing image 93: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_100.jpg
# Processing image 94: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_101.jpg
# Processing image 95: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_102.jpg
# Processing image 96: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_103.jpg
# Processing image 97: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_104.jpg
# Processing image 98: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_105.jpg
# Processing image 99: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_106.jpg
# Processing image 100: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_107.jpg
# Processing image 101: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_108.jpg
# Processing image 102: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_109.jpg
# Processing image 103: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_110.jpg
# Processing image 104: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_111.jpg
# Processing image 105: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_112.jpg
# Processing image 106: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_113.jpg
# Processing image 107: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_114.jpg
# Processing image 108: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_115.jpg
# Processing image 109: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_116.jpg
# Processing image 110: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_117.jpg
# Processing image 111: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_118.jpg
# Processing image 112: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_119.jpg
# Processing image 113: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_120.jpg
# Processing image 114: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_121.jpg
# Processing image 115: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_122.jpg
# Processing image 116: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_123.jpg
# Processing image 117: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_124.jpg
# Processing image 118: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_125.jpg
# Processing image 119: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_126.jpg
# Processing image 120: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_127.jpg
# Processing image 121: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_128.jpg
# Processing image 122: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_129.jpg
# Processing image 123: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_130.jpg
# Processing image 124: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_131.jpg
# Processing image 125: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_132.jpg
# Processing image 126: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_133.jpg
# Processing image 127: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_134.jpg
# Processing image 128: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_135.jpg
# Processing image 129: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_136.jpg
# Processing image 130: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_137.jpg
# Processing image 131: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_138.jpg
# Processing image 132: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_139.jpg
# Processing image 133: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_140.jpg
# Processing image 134: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_142.jpg
# Processing image 135: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_143.jpg
# Processing image 136: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_144.jpg
# Processing image 137: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_145.jpg
# Processing image 138: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_146.jpg
# Processing image 139: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_147.jpg
# Processing image 140: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_148.jpg
# Processing image 141: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_149.jpg
# Processing image 142: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_150.jpg
# Processing image 143: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_151.jpg
# Processing image 144: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_152.jpg
# Processing image 145: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_153.jpg
# Processing image 146: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_154.jpg
# Processing image 147: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_155.jpg
# Processing image 148: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_156.jpg
# Processing image 149: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_157.jpg
# Processing image 150: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_158.jpg
# Processing image 151: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_160.jpg
# Processing image 152: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_161.jpg
# Processing image 153: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_162.jpg
# Processing image 154: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_163.jpg
# Processing image 155: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_164.jpg
# Processing image 156: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_165.jpg
# Processing image 157: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_169.jpg
# Processing image 158: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_170.jpg
# Processing image 159: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_171.jpg
# Processing image 160: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_172.jpg
# Processing image 161: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_173.jpg
# Processing image 162: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_174.jpg
# Processing image 163: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_178.jpg
# Processing image 164: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_180.jpg
# Processing image 165: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_181.jpg
# Processing image 166: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_182.jpg
# Processing image 167: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_183.jpg
# Processing image 168: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_184.jpg
# Processing image 169: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_185.jpg
# Processing image 170: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_186.jpg
# Processing image 171: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_187.jpg
# Processing image 172: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_188.jpg
# Processing image 173: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_189.jpg
# Processing image 174: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_190.jpg
# Processing image 175: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_191.jpg
# Processing image 176: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_192.jpg
# Processing image 177: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_193.jpg
# Processing image 178: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_194.jpg
# Processing image 179: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_195.jpg
# Processing image 180: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_196.jpg
# Processing image 181: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_197.jpg
# Processing image 182: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_198.jpg
# Processing image 183: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_199.jpg
# Processing image 184: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_200.jpg
# Processing image 185: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_201.jpg
# Processing image 186: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_202.jpg
# Processing image 187: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_203.jpg
# Processing image 188: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_204.jpg
# Processing image 189: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_205.jpg
# Processing image 190: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_206.jpg
# Processing image 191: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_207.jpg
# Processing image 192: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_208.jpg
# Processing image 193: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_209.jpg
# Processing image 194: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_212.jpg
# Processing image 195: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_213.jpg
# Processing image 196: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_214.jpg
# Processing image 197: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_218.jpg
# Processing image 198: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_219.jpg
# Processing image 199: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_220.jpg
# Processing image 200: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_224.jpg
# Processing image 201: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_225.jpg
# Processing image 202: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_226.jpg
# Processing image 203: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_227.jpg
# Processing image 204: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_230.jpg
# Processing image 205: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_231.jpg
# Processing image 206: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_232.jpg
# Processing image 207: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_233.jpg
# Processing image 208: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_234.jpg
# Processing image 209: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_235.jpg
# Processing image 210: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_236.jpg
# Processing image 211: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_237.jpg
# Processing image 212: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_238.jpg
# Processing image 213: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_239.jpg
# Processing image 214: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_240.jpg
# Processing image 215: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_241.jpg
# Processing image 216: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_242.jpg
# Processing image 217: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_243.jpg
# Processing image 218: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_244.jpg
# Processing image 219: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_245.jpg
# Processing image 220: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_246.jpg
# Processing image 221: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_247.jpg
# Processing image 222: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_248.jpg
# Processing image 223: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_249.jpg
# Processing image 224: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_250.jpg
# Processing image 225: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_251.jpg
# Processing image 226: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_252.jpg
# Processing image 227: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_253.jpg
# Processing image 228: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_254.jpg
# Processing image 229: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_255.jpg
# Processing image 230: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_256.jpg
# Processing image 231: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_257.jpg
# Processing image 232: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_258.jpg
# Processing image 233: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_259.jpg
# Processing image 234: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_260.jpg
# Processing image 235: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_261.jpg
# Processing image 236: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_262.jpg
# Processing image 237: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_263.jpg
# Processing image 238: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_264.jpg
# Processing image 239: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_265.jpg
# Processing image 240: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_266.jpg
# Processing image 241: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_267.jpg
# Processing image 242: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_268.jpg
# Processing image 243: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_269.jpg
# Processing image 244: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_270.jpg
# Processing image 245: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_271.jpg
# Processing image 246: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_272.jpg
# Processing image 247: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_273.jpg
# Processing image 248: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_274.jpg
# Processing image 249: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_275.jpg
# Processing image 250: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_276.jpg
# Processing image 251: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_277.jpg
# Processing image 252: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_278.jpg
# Processing image 253: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_279.jpg
# Processing image 254: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_280.jpg
# Processing image 255: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_281.jpg
# Processing image 256: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_282.jpg
# Processing image 257: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_283.jpg
# Processing image 258: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_284.jpg
# Processing image 259: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_285.jpg
# Processing image 260: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_286.jpg
# Processing image 261: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_287.jpg
# Processing image 262: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_288.jpg
# Processing image 263: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_289.jpg
# Processing image 264: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_290.jpg
# Processing image 265: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_291.jpg
# Processing image 266: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_292.jpg
# Processing image 267: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_293.jpg
# Processing image 268: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_294.jpg
# Processing image 269: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_295.jpg
# Processing image 270: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_296.jpg
# Processing image 271: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_297.jpg
# Processing image 272: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_298.jpg
# Processing image 273: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_299.jpg
# Processing image 274: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_300.jpg
# Processing image 275: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_301.jpg
# Processing image 276: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_302.jpg
# Processing image 277: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_303.jpg
# Processing image 278: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_304.jpg
# Processing image 279: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_305.jpg
# Processing image 280: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_306.jpg
# Processing image 281: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_307.jpg
# Processing image 282: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_308.jpg
# Processing image 283: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_309.jpg
# Processing image 284: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_310.jpg
# Processing image 285: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_311.jpg
# Processing image 286: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_312.jpg
# Processing image 287: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_313.jpg
# Processing image 288: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_314.jpg
# Processing image 289: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_315.jpg
# Processing image 290: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_316.jpg
# Processing image 291: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_317.jpg
# Processing image 292: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_318.jpg
# Processing image 293: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_319.jpg
# Processing image 294: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_320.jpg
# Processing image 295: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_321.jpg
# Processing image 296: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_322.jpg
# Processing image 297: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_323.jpg
# Processing image 298: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_324.jpg
# Processing image 299: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_325.jpg
# Processing image 300: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_326.jpg
# Processing image 301: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_327.jpg
# Processing image 302: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_328.jpg
# Processing image 303: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_329.jpg
# Processing image 304: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_330.jpg
# Processing image 305: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_331.jpg
# Processing image 306: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_332.jpg
# Processing image 307: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_333.jpg
# Processing image 308: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_334.jpg
# Processing image 309: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_335.jpg
# Processing image 310: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_347.jpg
# Processing image 311: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_348.jpg
# Processing image 312: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_349.jpg
# Processing image 313: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_350.jpg
# Processing image 314: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_353.jpg
# Processing image 315: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_354.jpg
# Processing image 316: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_355.jpg
# Processing image 317: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_356.jpg
# Processing image 318: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_357.jpg
# Processing image 319: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_358.jpg
# Processing image 320: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_359.jpg
# Processing image 321: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_360.jpg
# Processing image 322: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_361.jpg
# Processing image 323: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_362.jpg
# Processing image 324: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_363.jpg
# Processing image 325: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_364.jpg
# Processing image 326: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_365.jpg
# Processing image 327: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_366.jpg
# Processing image 328: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_367.jpg
# Processing image 329: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_368.jpg
# Processing image 330: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_369.jpg
# Processing image 331: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_370.jpg
# Processing image 332: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_371.jpg
# Processing image 333: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_372.jpg
# Processing image 334: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_373.jpg
# Processing image 335: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_374.jpg
# Processing image 336: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222829_375.jpg
# Processing image 337: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_001.jpg
# Processing image 338: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_002.jpg
# Processing image 339: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_003.jpg
# Processing image 340: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_004.jpg
# Processing image 341: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_005.jpg
# Processing image 342: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_006.jpg
# Processing image 343: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_007.jpg
# Processing image 344: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_008.jpg
# Processing image 345: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_009.jpg
# Processing image 346: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_010.jpg
# Processing image 347: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_011.jpg
# Processing image 348: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_012.jpg
# Processing image 349: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_013.jpg
# Processing image 350: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_014.jpg
# Processing image 351: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_015.jpg
# Processing image 352: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_016.jpg
# Processing image 353: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_017.jpg
# Processing image 354: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_018.jpg
# Processing image 355: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_019.jpg
# Processing image 356: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_020.jpg
# Processing image 357: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_021.jpg
# Processing image 358: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_022.jpg
# Processing image 359: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_023.jpg
# Processing image 360: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_024.jpg
# Processing image 361: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_025.jpg
# Processing image 362: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_026.jpg
# Processing image 363: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_030.jpg
# Processing image 364: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_031.jpg
# Processing image 365: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_032.jpg
# Processing image 366: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_033.jpg
# Processing image 367: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_034.jpg
# Processing image 368: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_035.jpg
# Processing image 369: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_036.jpg
# Processing image 370: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_037.jpg
# Processing image 371: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_038.jpg
# Processing image 372: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_039.jpg
# Processing image 373: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_040.jpg
# Processing image 374: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_041.jpg
# Processing image 375: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_042.jpg
# Processing image 376: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_043.jpg
# Processing image 377: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_044.jpg
# Processing image 378: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_045.jpg
# Processing image 379: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_046.jpg
# Processing image 380: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_047.jpg
# Processing image 381: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_048.jpg
# Processing image 382: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_049.jpg
# Processing image 383: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_050.jpg
# Processing image 384: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_051.jpg
# Processing image 385: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_052.jpg
# Processing image 386: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_053.jpg
# Processing image 387: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_054.jpg
# Processing image 388: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_055.jpg
# Processing image 389: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_056.jpg
# Processing image 390: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_057.jpg
# Processing image 391: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_058.jpg
# Processing image 392: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_059.jpg
# Processing image 393: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_060.jpg
# Processing image 394: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_061.jpg
# Processing image 395: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_062.jpg
# Processing image 396: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_063.jpg
# Processing image 397: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_064.jpg
# Processing image 398: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_065.jpg
# Processing image 399: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_066.jpg
# Processing image 400: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_067.jpg
# Processing image 401: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_068.jpg
# Processing image 402: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_069.jpg
# Processing image 403: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_070.jpg
# Processing image 404: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_071.jpg
# Processing image 405: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_072.jpg
# Processing image 406: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_073.jpg
# Processing image 407: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250307_222838_074.jpg
# ...
# Processing image 3303: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_064.jpg
# Processing image 3304: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_065.jpg
# Processing image 3305: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_066.jpg
# Processing image 3306: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_067.jpg
# Processing image 3307: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_068.jpg
# Processing image 3308: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_069.jpg
# Processing image 3309: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_070.jpg
# Processing image 3310: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_071.jpg
# Processing image 3311: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_072.jpg
# Processing image 3312: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_073.jpg
# Processing image 3313: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_074.jpg
# Processing image 3314: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_075.jpg
# Processing image 3315: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_076.jpg
# Processing image 3316: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_077.jpg
# Processing image 3317: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_078.jpg
# Processing image 3318: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_079.jpg
# Processing image 3319: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_080.jpg
# Processing image 3320: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_081.jpg
# Processing image 3321: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_082.jpg
# Processing image 3322: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_083.jpg
# Processing image 3323: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_084.jpg
# Processing image 3324: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_085.jpg
# Processing image 3325: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_086.jpg
# Processing image 3326: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_087.jpg
# Processing image 3327: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_088.jpg
# Processing image 3328: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_089.jpg
# Processing image 3329: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_090.jpg
# Processing image 3330: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_091.jpg
# Processing image 3331: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_092.jpg
# Processing image 3332: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_093.jpg
# Processing image 3333: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_094.jpg
# Processing image 3334: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_095.jpg
# Processing image 3335: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_096.jpg
# Processing image 3336: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_097.jpg
# Processing image 3337: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_098.jpg
# Processing image 3338: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_099.jpg
# Processing image 3339: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_100.jpg
# Processing image 3340: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_101.jpg
# Processing image 3341: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_102.jpg
# Processing image 3342: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_103.jpg
# Processing image 3343: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_104.jpg
# Processing image 3344: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_105.jpg
# Processing image 3345: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_106.jpg
# Processing image 3346: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_107.jpg
# Processing image 3347: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_108.jpg
# Processing image 3348: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_109.jpg
# Processing image 3349: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_110.jpg
# Processing image 3350: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_111.jpg
# Processing image 3351: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_112.jpg
# Processing image 3352: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_113.jpg
# Processing image 3353: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_114.jpg
# Processing image 3354: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_115.jpg
# Processing image 3355: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_116.jpg
# Processing image 3356: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_117.jpg
# Processing image 3357: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_118.jpg
# Processing image 3358: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_119.jpg
# Processing image 3359: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_120.jpg
# Processing image 3360: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_121.jpg
# Processing image 3361: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_122.jpg
# Processing image 3362: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_123.jpg
# Processing image 3363: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_124.jpg
# Processing image 3364: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_125.jpg
# Processing image 3365: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_126.jpg
# Processing image 3366: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_127.jpg
# Processing image 3367: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_128.jpg
# Processing image 3368: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_129.jpg
# Processing image 3369: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_130.jpg
# Processing image 3370: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_131.jpg
# Processing image 3371: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_132.jpg
# Processing image 3372: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_133.jpg
# Processing image 3373: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_134.jpg
# Processing image 3374: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092557_138.jpg
# Processing image 3375: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_001.jpg
# Processing image 3376: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_002.jpg
# Processing image 3377: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_003.jpg
# Processing image 3378: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_004.jpg
# Processing image 3379: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_005.jpg
# Processing image 3380: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_008.jpg
# Processing image 3381: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_013.jpg
# Processing image 3382: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_014.jpg
# Processing image 3383: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_015.jpg
# Processing image 3384: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_016.jpg
# Processing image 3385: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_017.jpg
# Processing image 3386: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_018.jpg
# Processing image 3387: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_019.jpg
# Processing image 3388: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_020.jpg
# Processing image 3389: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_021.jpg
# Processing image 3390: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_022.jpg
# Processing image 3391: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_023.jpg
# Processing image 3392: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_024.jpg
# Processing image 3393: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_025.jpg
# Processing image 3394: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_026.jpg
# Processing image 3395: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_039.jpg
# Processing image 3396: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_040.jpg
# Processing image 3397: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_041.jpg
# Processing image 3398: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_042.jpg
# Processing image 3399: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_043.jpg
# Processing image 3400: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_044.jpg
# Processing image 3401: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_045.jpg
# Processing image 3402: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_046.jpg
# Processing image 3403: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_047.jpg
# Processing image 3404: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_048.jpg
# Processing image 3405: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_049.jpg
# Processing image 3406: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_050.jpg
# Processing image 3407: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_051.jpg
# Processing image 3408: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_052.jpg
# Processing image 3409: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_053.jpg
# Processing image 3410: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_054.jpg
# Processing image 3411: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_055.jpg
# Processing image 3412: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_056.jpg
# Processing image 3413: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_057.jpg
# Processing image 3414: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_058.jpg
# Processing image 3415: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_059.jpg
# Processing image 3416: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_060.jpg
# Processing image 3417: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_061.jpg
# Processing image 3418: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_062.jpg
# Processing image 3419: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_063.jpg
# Processing image 3420: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_064.jpg
# Processing image 3421: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_065.jpg
# Processing image 3422: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_066.jpg
# Processing image 3423: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_067.jpg
# Processing image 3424: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_068.jpg
# Processing image 3425: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_069.jpg
# Processing image 3426: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_070.jpg
# Processing image 3427: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_071.jpg
# Processing image 3428: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_072.jpg
# Processing image 3429: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_073.jpg
# Processing image 3430: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_074.jpg
# Processing image 3431: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_075.jpg
# Processing image 3432: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_076.jpg
# Processing image 3433: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_077.jpg
# Processing image 3434: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_078.jpg
# Processing image 3435: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_079.jpg
# Processing image 3436: /content/drive/MyDrive/ComputerVision/dataset_multi_label/cropped_faces/20250321_092559_080.jpg

# %%
np.save('images.npy', images)
np.save('labels.npy', labels)

# %% [markdown]
# #### Save image and label

# %%
images = np.load('images.npy')
labels = np.load('labels.npy')

# %% [markdown]
# #### Data augmentation

# %%
# Data Augmentation for training images
train_datagen = ImageDataGenerator(
    rescale=1./255,  # Rescaling images to range [0, 1]
    rotation_range=15,  # Random rotation between -15 and 15 degrees
    width_shift_range=0.2,  # Random horizontal shift
    height_shift_range=0.2,  # Random vertical shift
    shear_range=0.2,  # Random shear transformation
    zoom_range=0.2,  # Random zoom
    horizontal_flip=True,  # Random horizontal flip
    fill_mode='nearest'  # Fill mode for empty pixels after transformation
)

# Data Augmentation for validation images (usually, we don't augment validation data)
val_datagen = ImageDataGenerator(rescale=1./255)

# %%
# Split the data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(images, labels, test_size=0.2, random_state=42)

# %% [markdown]
# #### Apply the augmentation to the data

# %%
# Lưu ý: ImageDataGenerator.flow() nhận đầu vào là dữ liệu numpy
train_generator = train_datagen.flow(X_train, y_train, batch_size=32)
val_generator = val_datagen.flow(X_val, y_val, batch_size=32)

# %% [markdown]
# ### Build the CNN Model

# %%
from tensorflow.keras.applications import MobileNetV2 # Hoặc EfficientNetB0
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.optimizers import Adam

def build_model(input_shape=(224, 224, 3), num_classes=5):
    # Load pre-trained base model (không bao gồm lớp fully connected cuối)
    base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=input_shape)

    # Đóng băng các lớp của base model (để không huấn luyện lại chúng ban đầu)
    base_model.trainable = False # Quan trọng!

    x = base_model.output
    x = GlobalAveragePooling2D()(x) # Giảm chiều dữ liệu
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.5)(x)
    predictions = Dense(num_classes, activation='sigmoid')(x) # Sử dụng sigmoid cho multi-label

    model = Model(inputs=base_model.input, outputs=predictions)

    model.compile(optimizer=Adam(learning_rate=1e-4),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

    return model

model = build_model()
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1             │ (None, 224, 224, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv1 (Conv2D)            │ (None, 112, 112, 32)   │            864 │ input_layer_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ bn_Conv1                  │ (None, 112, 112, 32)   │            128 │ Conv1[0][0]            │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv1_relu (ReLU)         │ (None, 112, 112, 32)   │              0 │ bn_Conv1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_depthwise   │ (None, 112, 112, 32)   │            288 │ Conv1_relu[0][0]       │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_depthwise_… │ (None, 112, 112, 32)   │            128 │ expanded_conv_depthwi… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_depthwise_… │ (None, 112, 112, 32)   │              0 │ expanded_conv_depthwi… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_project     │ (None, 112, 112, 16)   │            512 │ expanded_conv_depthwi… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_project_BN  │ (None, 112, 112, 16)   │             64 │ expanded_conv_project… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_expand (Conv2D)   │ (None, 112, 112, 96)   │          1,536 │ expanded_conv_project… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_expand_BN         │ (None, 112, 112, 96)   │            384 │ block_1_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_expand_relu       │ (None, 112, 112, 96)   │              0 │ block_1_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_pad               │ (None, 113, 113, 96)   │              0 │ block_1_expand_relu[0… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_depthwise         │ (None, 56, 56, 96)     │            864 │ block_1_pad[0][0]      │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_depthwise_BN      │ (None, 56, 56, 96)     │            384 │ block_1_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_depthwise_relu    │ (None, 56, 56, 96)     │              0 │ block_1_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_project (Conv2D)  │ (None, 56, 56, 24)     │          2,304 │ block_1_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_project_BN        │ (None, 56, 56, 24)     │             96 │ block_1_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_expand (Conv2D)   │ (None, 56, 56, 144)    │          3,456 │ block_1_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_expand_BN         │ (None, 56, 56, 144)    │            576 │ block_2_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_expand_relu       │ (None, 56, 56, 144)    │              0 │ block_2_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_depthwise         │ (None, 56, 56, 144)    │          1,296 │ block_2_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_depthwise_BN      │ (None, 56, 56, 144)    │            576 │ block_2_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_depthwise_relu    │ (None, 56, 56, 144)    │              0 │ block_2_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_project (Conv2D)  │ (None, 56, 56, 24)     │          3,456 │ block_2_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_project_BN        │ (None, 56, 56, 24)     │             96 │ block_2_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_add (Add)         │ (None, 56, 56, 24)     │              0 │ block_1_project_BN[0]… │
# │                           │                        │                │ block_2_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_expand (Conv2D)   │ (None, 56, 56, 144)    │          3,456 │ block_2_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_expand_BN         │ (None, 56, 56, 144)    │            576 │ block_3_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_expand_relu       │ (None, 56, 56, 144)    │              0 │ block_3_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_pad               │ (None, 57, 57, 144)    │              0 │ block_3_expand_relu[0… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_depthwise         │ (None, 28, 28, 144)    │          1,296 │ block_3_pad[0][0]      │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_depthwise_BN      │ (None, 28, 28, 144)    │            576 │ block_3_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_depthwise_relu    │ (None, 28, 28, 144)    │              0 │ block_3_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_project (Conv2D)  │ (None, 28, 28, 32)     │          4,608 │ block_3_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_project_BN        │ (None, 28, 28, 32)     │            128 │ block_3_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_expand (Conv2D)   │ (None, 28, 28, 192)    │          6,144 │ block_3_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_expand_BN         │ (None, 28, 28, 192)    │            768 │ block_4_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_expand_relu       │ (None, 28, 28, 192)    │              0 │ block_4_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_depthwise         │ (None, 28, 28, 192)    │          1,728 │ block_4_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_depthwise_BN      │ (None, 28, 28, 192)    │            768 │ block_4_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_depthwise_relu    │ (None, 28, 28, 192)    │              0 │ block_4_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_project (Conv2D)  │ (None, 28, 28, 32)     │          6,144 │ block_4_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_project_BN        │ (None, 28, 28, 32)     │            128 │ block_4_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_add (Add)         │ (None, 28, 28, 32)     │              0 │ block_3_project_BN[0]… │
# │                           │                        │                │ block_4_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_expand (Conv2D)   │ (None, 28, 28, 192)    │          6,144 │ block_4_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_expand_BN         │ (None, 28, 28, 192)    │            768 │ block_5_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_expand_relu       │ (None, 28, 28, 192)    │              0 │ block_5_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_depthwise         │ (None, 28, 28, 192)    │          1,728 │ block_5_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_depthwise_BN      │ (None, 28, 28, 192)    │            768 │ block_5_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_depthwise_relu    │ (None, 28, 28, 192)    │              0 │ block_5_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_project (Conv2D)  │ (None, 28, 28, 32)     │          6,144 │ block_5_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_project_BN        │ (None, 28, 28, 32)     │            128 │ block_5_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_add (Add)         │ (None, 28, 28, 32)     │              0 │ block_4_add[0][0],     │
# │                           │                        │                │ block_5_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_expand (Conv2D)   │ (None, 28, 28, 192)    │          6,144 │ block_5_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_expand_BN         │ (None, 28, 28, 192)    │            768 │ block_6_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_expand_relu       │ (None, 28, 28, 192)    │              0 │ block_6_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_pad               │ (None, 29, 29, 192)    │              0 │ block_6_expand_relu[0… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_depthwise         │ (None, 14, 14, 192)    │          1,728 │ block_6_pad[0][0]      │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_depthwise_BN      │ (None, 14, 14, 192)    │            768 │ block_6_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_depthwise_relu    │ (None, 14, 14, 192)    │              0 │ block_6_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_project (Conv2D)  │ (None, 14, 14, 64)     │         12,288 │ block_6_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_project_BN        │ (None, 14, 14, 64)     │            256 │ block_6_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_expand (Conv2D)   │ (None, 14, 14, 384)    │         24,576 │ block_6_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_expand_BN         │ (None, 14, 14, 384)    │          1,536 │ block_7_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_expand_relu       │ (None, 14, 14, 384)    │              0 │ block_7_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_depthwise         │ (None, 14, 14, 384)    │          3,456 │ block_7_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_depthwise_BN      │ (None, 14, 14, 384)    │          1,536 │ block_7_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_depthwise_relu    │ (None, 14, 14, 384)    │              0 │ block_7_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_project (Conv2D)  │ (None, 14, 14, 64)     │         24,576 │ block_7_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_project_BN        │ (None, 14, 14, 64)     │            256 │ block_7_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_add (Add)         │ (None, 14, 14, 64)     │              0 │ block_6_project_BN[0]… │
# │                           │                        │                │ block_7_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_expand (Conv2D)   │ (None, 14, 14, 384)    │         24,576 │ block_7_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_expand_BN         │ (None, 14, 14, 384)    │          1,536 │ block_8_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_expand_relu       │ (None, 14, 14, 384)    │              0 │ block_8_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_depthwise         │ (None, 14, 14, 384)    │          3,456 │ block_8_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_depthwise_BN      │ (None, 14, 14, 384)    │          1,536 │ block_8_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_depthwise_relu    │ (None, 14, 14, 384)    │              0 │ block_8_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_project (Conv2D)  │ (None, 14, 14, 64)     │         24,576 │ block_8_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_project_BN        │ (None, 14, 14, 64)     │            256 │ block_8_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_add (Add)         │ (None, 14, 14, 64)     │              0 │ block_7_add[0][0],     │
# │                           │                        │                │ block_8_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_expand (Conv2D)   │ (None, 14, 14, 384)    │         24,576 │ block_8_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_expand_BN         │ (None, 14, 14, 384)    │          1,536 │ block_9_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_expand_relu       │ (None, 14, 14, 384)    │              0 │ block_9_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_depthwise         │ (None, 14, 14, 384)    │          3,456 │ block_9_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_depthwise_BN      │ (None, 14, 14, 384)    │          1,536 │ block_9_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_depthwise_relu    │ (None, 14, 14, 384)    │              0 │ block_9_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_project (Conv2D)  │ (None, 14, 14, 64)     │         24,576 │ block_9_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_project_BN        │ (None, 14, 14, 64)     │            256 │ block_9_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_add (Add)         │ (None, 14, 14, 64)     │              0 │ block_8_add[0][0],     │
# │                           │                        │                │ block_9_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_expand (Conv2D)  │ (None, 14, 14, 384)    │         24,576 │ block_9_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_expand_BN        │ (None, 14, 14, 384)    │          1,536 │ block_10_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_expand_relu      │ (None, 14, 14, 384)    │              0 │ block_10_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_depthwise        │ (None, 14, 14, 384)    │          3,456 │ block_10_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_depthwise_BN     │ (None, 14, 14, 384)    │          1,536 │ block_10_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_depthwise_relu   │ (None, 14, 14, 384)    │              0 │ block_10_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_project (Conv2D) │ (None, 14, 14, 96)     │         36,864 │ block_10_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_project_BN       │ (None, 14, 14, 96)     │            384 │ block_10_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_expand (Conv2D)  │ (None, 14, 14, 576)    │         55,296 │ block_10_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_expand_BN        │ (None, 14, 14, 576)    │          2,304 │ block_11_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_expand_relu      │ (None, 14, 14, 576)    │              0 │ block_11_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_depthwise        │ (None, 14, 14, 576)    │          5,184 │ block_11_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_depthwise_BN     │ (None, 14, 14, 576)    │          2,304 │ block_11_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_depthwise_relu   │ (None, 14, 14, 576)    │              0 │ block_11_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_project (Conv2D) │ (None, 14, 14, 96)     │         55,296 │ block_11_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_project_BN       │ (None, 14, 14, 96)     │            384 │ block_11_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_add (Add)        │ (None, 14, 14, 96)     │              0 │ block_10_project_BN[0… │
# │                           │                        │                │ block_11_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_expand (Conv2D)  │ (None, 14, 14, 576)    │         55,296 │ block_11_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_expand_BN        │ (None, 14, 14, 576)    │          2,304 │ block_12_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_expand_relu      │ (None, 14, 14, 576)    │              0 │ block_12_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_depthwise        │ (None, 14, 14, 576)    │          5,184 │ block_12_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_depthwise_BN     │ (None, 14, 14, 576)    │          2,304 │ block_12_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_depthwise_relu   │ (None, 14, 14, 576)    │              0 │ block_12_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_project (Conv2D) │ (None, 14, 14, 96)     │         55,296 │ block_12_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_project_BN       │ (None, 14, 14, 96)     │            384 │ block_12_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_add (Add)        │ (None, 14, 14, 96)     │              0 │ block_11_add[0][0],    │
# │                           │                        │                │ block_12_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_expand (Conv2D)  │ (None, 14, 14, 576)    │         55,296 │ block_12_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_expand_BN        │ (None, 14, 14, 576)    │          2,304 │ block_13_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_expand_relu      │ (None, 14, 14, 576)    │              0 │ block_13_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_pad              │ (None, 15, 15, 576)    │              0 │ block_13_expand_relu[… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_depthwise        │ (None, 7, 7, 576)      │          5,184 │ block_13_pad[0][0]     │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_depthwise_BN     │ (None, 7, 7, 576)      │          2,304 │ block_13_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_depthwise_relu   │ (None, 7, 7, 576)      │              0 │ block_13_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_project (Conv2D) │ (None, 7, 7, 160)      │         92,160 │ block_13_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_project_BN       │ (None, 7, 7, 160)      │            640 │ block_13_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_expand (Conv2D)  │ (None, 7, 7, 960)      │        153,600 │ block_13_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_expand_BN        │ (None, 7, 7, 960)      │          3,840 │ block_14_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_expand_relu      │ (None, 7, 7, 960)      │              0 │ block_14_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_depthwise        │ (None, 7, 7, 960)      │          8,640 │ block_14_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_depthwise_BN     │ (None, 7, 7, 960)      │          3,840 │ block_14_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_depthwise_relu   │ (None, 7, 7, 960)      │              0 │ block_14_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_project (Conv2D) │ (None, 7, 7, 160)      │        153,600 │ block_14_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_project_BN       │ (None, 7, 7, 160)      │            640 │ block_14_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_add (Add)        │ (None, 7, 7, 160)      │              0 │ block_13_project_BN[0… │
# │                           │                        │                │ block_14_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_expand (Conv2D)  │ (None, 7, 7, 960)      │        153,600 │ block_14_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_expand_BN        │ (None, 7, 7, 960)      │          3,840 │ block_15_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_expand_relu      │ (None, 7, 7, 960)      │              0 │ block_15_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_depthwise        │ (None, 7, 7, 960)      │          8,640 │ block_15_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_depthwise_BN     │ (None, 7, 7, 960)      │          3,840 │ block_15_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_depthwise_relu   │ (None, 7, 7, 960)      │              0 │ block_15_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_project (Conv2D) │ (None, 7, 7, 160)      │        153,600 │ block_15_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_project_BN       │ (None, 7, 7, 160)      │            640 │ block_15_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_add (Add)        │ (None, 7, 7, 160)      │              0 │ block_14_add[0][0],    │
# │                           │                        │                │ block_15_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_expand (Conv2D)  │ (None, 7, 7, 960)      │        153,600 │ block_15_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_expand_BN        │ (None, 7, 7, 960)      │          3,840 │ block_16_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_expand_relu      │ (None, 7, 7, 960)      │              0 │ block_16_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_depthwise        │ (None, 7, 7, 960)      │          8,640 │ block_16_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_depthwise_BN     │ (None, 7, 7, 960)      │          3,840 │ block_16_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_depthwise_relu   │ (None, 7, 7, 960)      │              0 │ block_16_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_project (Conv2D) │ (None, 7, 7, 320)      │        307,200 │ block_16_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_project_BN       │ (None, 7, 7, 320)      │          1,280 │ block_16_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv_1 (Conv2D)           │ (None, 7, 7, 1280)     │        409,600 │ block_16_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv_1_bn                 │ (None, 7, 7, 1280)     │          5,120 │ Conv_1[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ out_relu (ReLU)           │ (None, 7, 7, 1280)     │              0 │ Conv_1_bn[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 1280)           │              0 │ out_relu[0][0]         │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 128)            │        163,968 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 128)            │              0 │ dense_2[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_3 (Dense)           │ (None, 5)              │            645 │ dropout_1[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 2,422,597 (9.24 MB)
#  Trainable params: 164,613 (643.02 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %% [markdown]
# ### Train the Model CNN

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)
# Optional: Giảm learning rate khi val_loss không cải thiện
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6, verbose=1)

# Define the checkpoint callback
checkpoint_callback = ModelCheckpoint(
    'model_checkpoint.weights.h5',  # Changed the filepath to end with .weights.h5
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    mode='min',
    verbose=1
)

epochs = 10
batch_size = 32

history = model.fit(
    train_generator,
    epochs=epochs,
    validation_data=val_generator,
    callbacks=[checkpoint_callback, early_stopping, reduce_lr]
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step - accuracy: 0.3601 - loss: 0.5681
# Epoch 1: val_loss improved from inf to 0.33893, saving model to model_checkpoint.weights.h5
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 59s 555ms/step - accuracy: 0.3614 - loss: 0.5671 - val_accuracy: 0.6406 - val_loss: 0.3389 - learning_rate: 1.0000e-04
# Epoch 2/10
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.6060 - loss: 0.3849
# Epoch 2: val_loss improved from 0.33893 to 0.28308, saving model to model_checkpoint.weights.h5
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 31s 370ms/step - accuracy: 0.6063 - loss: 0.3847 - val_accuracy: 0.6797 - val_loss: 0.2831 - learning_rate: 1.0000e-04
# Epoch 3/10
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.6492 - loss: 0.3317
# Epoch 3: val_loss improved from 0.28308 to 0.24828, saving model to model_checkpoint.weights.h5
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 33s 390ms/step - accuracy: 0.6493 - loss: 0.3316 - val_accuracy: 0.7248 - val_loss: 0.2483 - learning_rate: 1.0000e-04
# Epoch 4/10
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 0.6781 - loss: 0.3103
# Epoch 4: val_loss improved from 0.24828 to 0.23053, saving model to model_checkpoint.weights.h5
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 31s 372ms/step - accuracy: 0.6783 - loss: 0.3102 - val_accuracy: 0.7564 - val_loss: 0.2305 - learning_rate: 1.0000e-04
# Epoch 5/10
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.7273 - loss: 0.2779
# Epoch 5: val_loss improved from 0.23053 to 0.21891, saving model to model_checkpoint.weights.h5
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 31s 369ms/step - accuracy: 0.7272 - loss: 0.2779 - val_accuracy: 0.7519 - val_loss: 0.2189 - learning_rate: 1.0000e-04
# Epoch 6/10
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.7310 - loss: 0.2653
# Epoch 6: val_loss improved from 0.21891 to 0.20150, saving model to model_checkpoint.weights.h5
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 32s 387ms/step - accuracy: 0.7310 - loss: 0.2652 - val_accuracy: 0.7835 - val_loss: 0.2015 - learning_rate: 1.0000e-04
# Epoch 7/10
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.7297 - loss: 0.2536
# Epoch 7: val_loss improved from 0.20150 to 0.19029, saving model to model_checkpoint.weights.h5
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 31s 373ms/step - accuracy: 0.7298 - loss: 0.2535 - val_accuracy: 0.8180 - val_loss: 0.1903 - learning_rate: 1.0000e-04
# Epoch 8/10
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - accuracy: 0.7738 - loss: 0.2349
# Epoch 8: val_loss improved from 0.19029 to 0.18466, saving model to model_checkpoint.weights.h5
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 31s 365ms/step - accuracy: 0.7737 - loss: 0.2349 - val_accuracy: 0.8180 - val_loss: 0.1847 - learning_rate: 1.0000e-04
# Epoch 9/10
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.7739 - loss: 0.2328
# Epoch 9: val_loss improved from 0.18466 to 0.18040, saving model to model_checkpoint.weights.h5
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 32s 384ms/step - accuracy: 0.7738 - loss: 0.2328 - val_accuracy: 0.8256 - val_loss: 0.1804 - learning_rate: 1.0000e-04
# Epoch 10/10
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - accuracy: 0.7692 - loss: 0.2249
# Epoch 10: val_loss improved from 0.18040 to 0.17618, saving model to model_checkpoint.weights.h5
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 31s 370ms/step - accuracy: 0.7692 - loss: 0.2249 - val_accuracy: 0.8226 - val_loss: 0.1762 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 10.

# %% [markdown]
# ### Evaluate the Model

# %%
loss, accuracy = model.evaluate(X_val, y_val)
print(f"Validation Loss: {loss}")
print(f"Validation Accuracy: {accuracy}")
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.2548 - loss: 0.5848
# Validation Loss: 0.6001015901565552
# Validation Accuracy: 0.2345864623785019

# %% [markdown]
# ###Save and Load the Model

# %%
model.save('sleepiness_detection_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ### Test model

# %%
from tensorflow.keras.models import load_model
model = load_model('sleepiness_detection_model.h5')
model.summary()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1             │ (None, 224, 224, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv1 (Conv2D)            │ (None, 112, 112, 32)   │            864 │ input_layer_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ bn_Conv1                  │ (None, 112, 112, 32)   │            128 │ Conv1[0][0]            │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv1_relu (ReLU)         │ (None, 112, 112, 32)   │              0 │ bn_Conv1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_depthwise   │ (None, 112, 112, 32)   │            288 │ Conv1_relu[0][0]       │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_depthwise_… │ (None, 112, 112, 32)   │            128 │ expanded_conv_depthwi… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_depthwise_… │ (None, 112, 112, 32)   │              0 │ expanded_conv_depthwi… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_project     │ (None, 112, 112, 16)   │            512 │ expanded_conv_depthwi… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_project_BN  │ (None, 112, 112, 16)   │             64 │ expanded_conv_project… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_expand (Conv2D)   │ (None, 112, 112, 96)   │          1,536 │ expanded_conv_project… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_expand_BN         │ (None, 112, 112, 96)   │            384 │ block_1_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_expand_relu       │ (None, 112, 112, 96)   │              0 │ block_1_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_pad               │ (None, 113, 113, 96)   │              0 │ block_1_expand_relu[0… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_depthwise         │ (None, 56, 56, 96)     │            864 │ block_1_pad[0][0]      │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_depthwise_BN      │ (None, 56, 56, 96)     │            384 │ block_1_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_depthwise_relu    │ (None, 56, 56, 96)     │              0 │ block_1_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_project (Conv2D)  │ (None, 56, 56, 24)     │          2,304 │ block_1_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_project_BN        │ (None, 56, 56, 24)     │             96 │ block_1_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_expand (Conv2D)   │ (None, 56, 56, 144)    │          3,456 │ block_1_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_expand_BN         │ (None, 56, 56, 144)    │            576 │ block_2_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_expand_relu       │ (None, 56, 56, 144)    │              0 │ block_2_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_depthwise         │ (None, 56, 56, 144)    │          1,296 │ block_2_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_depthwise_BN      │ (None, 56, 56, 144)    │            576 │ block_2_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_depthwise_relu    │ (None, 56, 56, 144)    │              0 │ block_2_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_project (Conv2D)  │ (None, 56, 56, 24)     │          3,456 │ block_2_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_project_BN        │ (None, 56, 56, 24)     │             96 │ block_2_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_add (Add)         │ (None, 56, 56, 24)     │              0 │ block_1_project_BN[0]… │
# │                           │                        │                │ block_2_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_expand (Conv2D)   │ (None, 56, 56, 144)    │          3,456 │ block_2_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_expand_BN         │ (None, 56, 56, 144)    │            576 │ block_3_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_expand_relu       │ (None, 56, 56, 144)    │              0 │ block_3_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_pad               │ (None, 57, 57, 144)    │              0 │ block_3_expand_relu[0… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_depthwise         │ (None, 28, 28, 144)    │          1,296 │ block_3_pad[0][0]      │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_depthwise_BN      │ (None, 28, 28, 144)    │            576 │ block_3_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_depthwise_relu    │ (None, 28, 28, 144)    │              0 │ block_3_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_project (Conv2D)  │ (None, 28, 28, 32)     │          4,608 │ block_3_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_project_BN        │ (None, 28, 28, 32)     │            128 │ block_3_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_expand (Conv2D)   │ (None, 28, 28, 192)    │          6,144 │ block_3_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_expand_BN         │ (None, 28, 28, 192)    │            768 │ block_4_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_expand_relu       │ (None, 28, 28, 192)    │              0 │ block_4_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_depthwise         │ (None, 28, 28, 192)    │          1,728 │ block_4_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_depthwise_BN      │ (None, 28, 28, 192)    │            768 │ block_4_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_depthwise_relu    │ (None, 28, 28, 192)    │              0 │ block_4_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_project (Conv2D)  │ (None, 28, 28, 32)     │          6,144 │ block_4_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_project_BN        │ (None, 28, 28, 32)     │            128 │ block_4_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_add (Add)         │ (None, 28, 28, 32)     │              0 │ block_3_project_BN[0]… │
# │                           │                        │                │ block_4_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_expand (Conv2D)   │ (None, 28, 28, 192)    │          6,144 │ block_4_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_expand_BN         │ (None, 28, 28, 192)    │            768 │ block_5_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_expand_relu       │ (None, 28, 28, 192)    │              0 │ block_5_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_depthwise         │ (None, 28, 28, 192)    │          1,728 │ block_5_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_depthwise_BN      │ (None, 28, 28, 192)    │            768 │ block_5_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_depthwise_relu    │ (None, 28, 28, 192)    │              0 │ block_5_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_project (Conv2D)  │ (None, 28, 28, 32)     │          6,144 │ block_5_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_project_BN        │ (None, 28, 28, 32)     │            128 │ block_5_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_add (Add)         │ (None, 28, 28, 32)     │              0 │ block_4_add[0][0],     │
# │                           │                        │                │ block_5_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_expand (Conv2D)   │ (None, 28, 28, 192)    │          6,144 │ block_5_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_expand_BN         │ (None, 28, 28, 192)    │            768 │ block_6_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_expand_relu       │ (None, 28, 28, 192)    │              0 │ block_6_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_pad               │ (None, 29, 29, 192)    │              0 │ block_6_expand_relu[0… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_depthwise         │ (None, 14, 14, 192)    │          1,728 │ block_6_pad[0][0]      │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_depthwise_BN      │ (None, 14, 14, 192)    │            768 │ block_6_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_depthwise_relu    │ (None, 14, 14, 192)    │              0 │ block_6_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_project (Conv2D)  │ (None, 14, 14, 64)     │         12,288 │ block_6_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_project_BN        │ (None, 14, 14, 64)     │            256 │ block_6_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_expand (Conv2D)   │ (None, 14, 14, 384)    │         24,576 │ block_6_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_expand_BN         │ (None, 14, 14, 384)    │          1,536 │ block_7_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_expand_relu       │ (None, 14, 14, 384)    │              0 │ block_7_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_depthwise         │ (None, 14, 14, 384)    │          3,456 │ block_7_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_depthwise_BN      │ (None, 14, 14, 384)    │          1,536 │ block_7_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_depthwise_relu    │ (None, 14, 14, 384)    │              0 │ block_7_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_project (Conv2D)  │ (None, 14, 14, 64)     │         24,576 │ block_7_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_project_BN        │ (None, 14, 14, 64)     │            256 │ block_7_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_add (Add)         │ (None, 14, 14, 64)     │              0 │ block_6_project_BN[0]… │
# │                           │                        │                │ block_7_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_expand (Conv2D)   │ (None, 14, 14, 384)    │         24,576 │ block_7_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_expand_BN         │ (None, 14, 14, 384)    │          1,536 │ block_8_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_expand_relu       │ (None, 14, 14, 384)    │              0 │ block_8_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_depthwise         │ (None, 14, 14, 384)    │          3,456 │ block_8_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_depthwise_BN      │ (None, 14, 14, 384)    │          1,536 │ block_8_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_depthwise_relu    │ (None, 14, 14, 384)    │              0 │ block_8_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_project (Conv2D)  │ (None, 14, 14, 64)     │         24,576 │ block_8_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_project_BN        │ (None, 14, 14, 64)     │            256 │ block_8_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_add (Add)         │ (None, 14, 14, 64)     │              0 │ block_7_add[0][0],     │
# │                           │                        │                │ block_8_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_expand (Conv2D)   │ (None, 14, 14, 384)    │         24,576 │ block_8_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_expand_BN         │ (None, 14, 14, 384)    │          1,536 │ block_9_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_expand_relu       │ (None, 14, 14, 384)    │              0 │ block_9_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_depthwise         │ (None, 14, 14, 384)    │          3,456 │ block_9_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_depthwise_BN      │ (None, 14, 14, 384)    │          1,536 │ block_9_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_depthwise_relu    │ (None, 14, 14, 384)    │              0 │ block_9_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_project (Conv2D)  │ (None, 14, 14, 64)     │         24,576 │ block_9_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_project_BN        │ (None, 14, 14, 64)     │            256 │ block_9_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_add (Add)         │ (None, 14, 14, 64)     │              0 │ block_8_add[0][0],     │
# │                           │                        │                │ block_9_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_expand (Conv2D)  │ (None, 14, 14, 384)    │         24,576 │ block_9_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_expand_BN        │ (None, 14, 14, 384)    │          1,536 │ block_10_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_expand_relu      │ (None, 14, 14, 384)    │              0 │ block_10_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_depthwise        │ (None, 14, 14, 384)    │          3,456 │ block_10_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_depthwise_BN     │ (None, 14, 14, 384)    │          1,536 │ block_10_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_depthwise_relu   │ (None, 14, 14, 384)    │              0 │ block_10_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_project (Conv2D) │ (None, 14, 14, 96)     │         36,864 │ block_10_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_project_BN       │ (None, 14, 14, 96)     │            384 │ block_10_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_expand (Conv2D)  │ (None, 14, 14, 576)    │         55,296 │ block_10_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_expand_BN        │ (None, 14, 14, 576)    │          2,304 │ block_11_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_expand_relu      │ (None, 14, 14, 576)    │              0 │ block_11_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_depthwise        │ (None, 14, 14, 576)    │          5,184 │ block_11_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_depthwise_BN     │ (None, 14, 14, 576)    │          2,304 │ block_11_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_depthwise_relu   │ (None, 14, 14, 576)    │              0 │ block_11_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_project (Conv2D) │ (None, 14, 14, 96)     │         55,296 │ block_11_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_project_BN       │ (None, 14, 14, 96)     │            384 │ block_11_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_add (Add)        │ (None, 14, 14, 96)     │              0 │ block_10_project_BN[0… │
# │                           │                        │                │ block_11_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_expand (Conv2D)  │ (None, 14, 14, 576)    │         55,296 │ block_11_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_expand_BN        │ (None, 14, 14, 576)    │          2,304 │ block_12_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_expand_relu      │ (None, 14, 14, 576)    │              0 │ block_12_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_depthwise        │ (None, 14, 14, 576)    │          5,184 │ block_12_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_depthwise_BN     │ (None, 14, 14, 576)    │          2,304 │ block_12_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_depthwise_relu   │ (None, 14, 14, 576)    │              0 │ block_12_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_project (Conv2D) │ (None, 14, 14, 96)     │         55,296 │ block_12_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_project_BN       │ (None, 14, 14, 96)     │            384 │ block_12_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_add (Add)        │ (None, 14, 14, 96)     │              0 │ block_11_add[0][0],    │
# │                           │                        │                │ block_12_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_expand (Conv2D)  │ (None, 14, 14, 576)    │         55,296 │ block_12_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_expand_BN        │ (None, 14, 14, 576)    │          2,304 │ block_13_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_expand_relu      │ (None, 14, 14, 576)    │              0 │ block_13_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_pad              │ (None, 15, 15, 576)    │              0 │ block_13_expand_relu[… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_depthwise        │ (None, 7, 7, 576)      │          5,184 │ block_13_pad[0][0]     │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_depthwise_BN     │ (None, 7, 7, 576)      │          2,304 │ block_13_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_depthwise_relu   │ (None, 7, 7, 576)      │              0 │ block_13_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_project (Conv2D) │ (None, 7, 7, 160)      │         92,160 │ block_13_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_project_BN       │ (None, 7, 7, 160)      │            640 │ block_13_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_expand (Conv2D)  │ (None, 7, 7, 960)      │        153,600 │ block_13_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_expand_BN        │ (None, 7, 7, 960)      │          3,840 │ block_14_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_expand_relu      │ (None, 7, 7, 960)      │              0 │ block_14_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_depthwise        │ (None, 7, 7, 960)      │          8,640 │ block_14_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_depthwise_BN     │ (None, 7, 7, 960)      │          3,840 │ block_14_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_depthwise_relu   │ (None, 7, 7, 960)      │              0 │ block_14_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_project (Conv2D) │ (None, 7, 7, 160)      │        153,600 │ block_14_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_project_BN       │ (None, 7, 7, 160)      │            640 │ block_14_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_add (Add)        │ (None, 7, 7, 160)      │              0 │ block_13_project_BN[0… │
# │                           │                        │                │ block_14_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_expand (Conv2D)  │ (None, 7, 7, 960)      │        153,600 │ block_14_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_expand_BN        │ (None, 7, 7, 960)      │          3,840 │ block_15_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_expand_relu      │ (None, 7, 7, 960)      │              0 │ block_15_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_depthwise        │ (None, 7, 7, 960)      │          8,640 │ block_15_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_depthwise_BN     │ (None, 7, 7, 960)      │          3,840 │ block_15_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_depthwise_relu   │ (None, 7, 7, 960)      │              0 │ block_15_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_project (Conv2D) │ (None, 7, 7, 160)      │        153,600 │ block_15_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_project_BN       │ (None, 7, 7, 160)      │            640 │ block_15_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_add (Add)        │ (None, 7, 7, 160)      │              0 │ block_14_add[0][0],    │
# │                           │                        │                │ block_15_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_expand (Conv2D)  │ (None, 7, 7, 960)      │        153,600 │ block_15_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_expand_BN        │ (None, 7, 7, 960)      │          3,840 │ block_16_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_expand_relu      │ (None, 7, 7, 960)      │              0 │ block_16_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_depthwise        │ (None, 7, 7, 960)      │          8,640 │ block_16_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_depthwise_BN     │ (None, 7, 7, 960)      │          3,840 │ block_16_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_depthwise_relu   │ (None, 7, 7, 960)      │              0 │ block_16_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_project (Conv2D) │ (None, 7, 7, 320)      │        307,200 │ block_16_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_project_BN       │ (None, 7, 7, 320)      │          1,280 │ block_16_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv_1 (Conv2D)           │ (None, 7, 7, 1280)     │        409,600 │ block_16_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv_1_bn                 │ (None, 7, 7, 1280)     │          5,120 │ Conv_1[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ out_relu (ReLU)           │ (None, 7, 7, 1280)     │              0 │ Conv_1_bn[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 1280)           │              0 │ out_relu[0][0]         │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 128)            │        163,968 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 128)            │              0 │ dense_2[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_3 (Dense)           │ (None, 5)              │            645 │ dropout_1[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 2,422,599 (9.24 MB)
#  Trainable params: 164,613 (643.02 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)
#  Optimizer params: 2 (12.00 B)

# %% [markdown]
# ### Predict

# %%
import numpy as np
import cv2
from tensorflow.keras.preprocessing.image import ImageDataGenerator

def predict(image_path):
    image = cv2.imread(image_path)
    image = cv2.resize(image, (224, 224))  # Resize image to 224x224
    image = image / 255.0  # Normalize the image

    image = np.expand_dims(image, axis=0)  # Add batch dimension

    prediction = model.predict(image)

    # Define the class labels
    class_labels = ['natural', 'sleepy_eye', 'yawn', 'rub_eye', 'look_away']

    # Print confidence for each class label
    for i, label in enumerate(class_labels):
        confidence = prediction[0][i]  # Get the confidence for the current label
        print(f"{label}: {confidence:.4f}")

    # Get the index of the class with the highest probability
    predicted_class_idx = np.argmax(prediction)

    # Get the predicted class label and its confidence
    predicted_class = class_labels[predicted_class_idx]
    confidence = prediction[0][predicted_class_idx]

    return predicted_class, confidence

# Example usage
image_path = '/content/drive/MyDrive/ComputerVision/dataset_multi_class/indian_2/natural/1000.jpg'
predicted_class, confidence = predict(image_path)
print(f"Predicted class with highest confidence: {predicted_class}, Confidence: {confidence:.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# natural: 0.0311
# sleepy_eye: 0.3771
# yawn: 0.0140
# rub_eye: 0.3256
# look_away: 0.4021
# Predicted class with highest confidence: look_away, Confidence: 0.4021
