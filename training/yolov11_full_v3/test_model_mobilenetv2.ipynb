# %% [markdown]
# ## MobilenetV2

# %%
import pandas as pd
import time
import os
from pathlib import Path
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, f1_score
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import cv2
from tensorflow.keras.models import load_model

# --- CẤU HÌNH ---
MODEL_PATH = "model/mobilenet-v2.h5"
CSV_PATH = "output1.csv" # File CSV chứa đường dẫn đến các ảnh ĐÃ ĐƯỢC CROP
IMAGE_BASE_DIR = "" # Để trống nếu đường dẫn trong CSV là tuyệt đối hoặc tương đối với thư mục script
OUTPUT_DIR = "mobilenetv2_precropped_evaluation_output_with_images1"
PROCESSED_IMAGES_SUBDIR = "processed_images" # Thư mục con để lưu ảnh đã vẽ
INPUT_SHAPE = (224, 224) # Kích thước đầu vào mà model MobileNetV2 mong đợi

CLASS_LABELS = ['natural', 'sleepy_eye', 'yawn', 'rub_eye', 'look_away']

# --- HÀM HỖ TRỢ ---
def preprocess_image_for_mobilenet(image_bgr, target_size=(224, 224)):
    """
    Tiền xử lý ảnh (đã crop) cho MobileNetV2.
    Input là ảnh BGR đọc từ cv2.imread.
    """
    if image_bgr is None or image_bgr.size == 0:
        print("Lỗi: Ảnh đầu vào cho tiền xử lý rỗng hoặc không hợp lệ.")
        return None
    
    # MobileNetV2 thường được huấn luyện với ảnh RGB
    image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)
    image_resized = cv2.resize(image_rgb, target_size)
    image_normalized = image_resized / 255.0
    image_normalized = image_normalized.astype(np.float32)
    image_batch = np.expand_dims(image_normalized, axis=0) # Thêm batch dimension
    return image_batch

def get_predicted_label_mobilenet(probabilities, class_labels_ordered):
    """
    Trích xuất nhãn dự đoán từ vector xác suất của MobileNetV2.
    Chọn nhãn có xác suất cao nhất.
    """
    
    highest_prob_idx = np.argmax(probabilities)
    predicted_label_str = class_labels_ordered[highest_prob_idx]
    return predicted_label_str

def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues, output_path="confusion_matrix.png"):
    if normalize:
        # Tránh chia cho 0 nếu một hàng toàn là 0 (không có mẫu nào của lớp đó)
        cm_sum = cm.sum(axis=1)[:, np.newaxis]
        with np.errstate(divide='ignore', invalid='ignore'):
            cm_normalized = np.where(cm_sum > 0, cm.astype('float') / cm_sum, 0)
        cm = cm_normalized # Gán lại cm sau khi chuẩn hóa an toàn
        
    plt.figure(figsize=(max(8, int(len(classes)*0.8) ), max(6, int(len(classes) * 0.6))))
    sns.heatmap(cm, annot=True, fmt=".2f" if normalize else "d", cmap=cmap, xticklabels=classes, yticklabels=classes)
    plt.title(title)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.savefig(output_path)
    print(f"Confusion matrix saved to {output_path}")

# --- CHƯƠNG TRÌNH CHÍNH ---
def main():
    output_dir_path = Path(OUTPUT_DIR)
    processed_images_path = output_dir_path / PROCESSED_IMAGES_SUBDIR
    output_dir_path.mkdir(parents=True, exist_ok=True)
    processed_images_path.mkdir(parents=True, exist_ok=True)

    print(f"Loading classification model from: {MODEL_PATH}")
    if not os.path.exists(MODEL_PATH):
        print(f"LỖI: Model phân loại không tìm thấy tại: {MODEL_PATH}")
        return
    try:
        classification_model = load_model(MODEL_PATH)
        print("Classification model loaded successfully.")
    except Exception as e:
        print(f"LỖI: Không thể tải model phân loại: {e}")
        return

    print(f"Loading CSV from: {CSV_PATH}")
    if not os.path.exists(CSV_PATH):
        print(f"LỖI: CSV file không tìm thấy tại: {CSV_PATH}")
        return
    df = pd.read_csv(CSV_PATH)

    true_labels_list = []
    predicted_labels_list = []
    inference_times_total = []

    print(f"\nBắt đầu dự đoán trên {len(df)} ảnh (đã crop sẵn). Ảnh đã xử lý sẽ được lưu vào '{processed_images_path}'")

    for index, row in df.iterrows():
        image_path_relative = row['original_file_path']
        true_label = row['labels'] # Nhãn thật từ CSV
        image_filename = Path(image_path_relative).name

        # Xử lý đường dẫn ảnh
        if IMAGE_BASE_DIR:
            base = Path(IMAGE_BASE_DIR)
            if not base.is_absolute(): base = Path.cwd() / base
            image_path_full_obj = base / image_path_relative
        else:
            image_path_full_obj = Path(image_path_relative)
            if not image_path_full_obj.is_absolute(): image_path_full_obj = Path.cwd() / image_path_full_obj
        image_path_full = str(image_path_full_obj.resolve())

        # Đọc ảnh (đã được crop)
        cropped_image_from_file = cv2.imread(image_path_full)
        
        predicted_label_for_image = ""
        output_image_to_save = None

        if cropped_image_from_file is None:
            print(f"CẢNH BÁO: Ảnh (đã crop) không tải được: {image_path_full}. Bỏ qua.")
            continue
        
        output_image_to_save = cropped_image_from_file.copy() # Ảnh này đã được crop
        start_time_total = time.time()

        # Tiền xử lý ảnh đã crop
        image_batch = preprocess_image_for_mobilenet(cropped_image_from_file, target_size=INPUT_SHAPE)
        
        if image_batch is not None:
            try:
                # Dự đoán bằng MobileNetV2
                predictions_proba = classification_model.predict(image_batch, verbose=0)[0]
                predicted_label_for_image = get_predicted_label_mobilenet(predictions_proba, CLASS_LABELS)
            except Exception as e:
                print(f"Lỗi khi dự đoán ảnh {image_filename} bằng model: {e}")
        else:
            print(f"Lỗi tiền xử lý ảnh (đã crop) cho: {image_filename}")

        end_time_total = time.time()
        inference_times_total.append(end_time_total - start_time_total)

        true_labels_list.append(true_label)
        predicted_labels_list.append(predicted_label_for_image)

        # Vẽ thông tin lên ảnh (đã crop)
        text_to_draw = f"Pred: {predicted_label_for_image}"
        true_text_to_draw = f"True: {true_label}"
        
        text_color = (0, 255, 0) # Xanh lá cho dự đoán đúng

        # Vì ảnh đã crop, vị trí vẽ text có thể cần điều chỉnh
        text_y_position = 30
        if output_image_to_save.shape[0] < 60: # Nếu ảnh quá nhỏ
            text_y_position = output_image_to_save.shape[0] // 4

        cv2.putText(output_image_to_save, text_to_draw, (10, text_y_position), 
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, text_color, 2)
        cv2.putText(output_image_to_save, true_text_to_draw, (10, output_image_to_save.shape[0] - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 0, 0), 2) # Xanh dương cho nhãn thật

        # Lưu ảnh đã vẽ
        save_path = processed_images_path / image_filename
        try:
            cv2.imwrite(str(save_path), output_image_to_save)
        except Exception as e:
            print(f"Lỗi khi lưu ảnh {save_path}: {e}")

        print(f"Ảnh: {image_filename} - True: {true_label}, Predicted: {predicted_label_for_image} (Time: {end_time_total - start_time_total:.4f}s)")

    # 3. Tính toán và lưu trữ kết quả
    if not true_labels_list or not predicted_labels_list:
        print("Không có dự đoán nào được thực hiện. Kết thúc.")
        return

    print("\n--- KẾT QUẢ ĐÁNH GIÁ (MobileNetV2 trên ảnh đã crop sẵn) ---")

    # Bao gồm tất cả các nhãn từ CSV, model và các nhãn lỗi có thể có
    cm_labels_ordered = sorted(list(set(true_labels_list + predicted_labels_list + CLASS_LABELS)))
    
    cm = confusion_matrix(true_labels_list, predicted_labels_list, labels=cm_labels_ordered)
    accuracy = accuracy_score(true_labels_list, predicted_labels_list)
    
    # Labels để báo cáo chi tiết (thường là các lớp model được huấn luyện)
    meaningful_labels_for_report = sorted(list(set(CLASS_LABELS).intersection(set(cm_labels_ordered))))
    
    if not meaningful_labels_for_report: # Nếu không có nhãn nào chung để báo cáo
        report_str = "Không có lớp chung giữa nhãn thật và dự đoán trong CLASS_LABELS để tạo báo cáo."
        print(report_str)
    else:
        report_str = classification_report(true_labels_list, predicted_labels_list, labels=meaningful_labels_for_report, zero_division=0, target_names=meaningful_labels_for_report)
    
    # Labels để tính F1 (chỉ các lớp chính, không tính lỗi)
    f1_labels_strict = meaningful_labels_for_report[:] # Sử dụng các nhãn đã lọc ở trên
    
    if not f1_labels_strict:
        f1_macro = 0.0
        f1_weighted = 0.0
        print("Cảnh báo: Không có nhãn phù hợp để tính F1 score chi tiết.")
    else:
        f1_macro = f1_score(true_labels_list, predicted_labels_list, average='macro', labels=f1_labels_strict, zero_division=0)
        f1_weighted = f1_score(true_labels_list, predicted_labels_list, average='weighted', labels=f1_labels_strict, zero_division=0)

    avg_inference_time = sum(inference_times_total) / len(inference_times_total) if inference_times_total else 0
    total_inference_time = sum(inference_times_total)

    print(f"Số lượng ảnh đã xử lý: {len(true_labels_list)}")
    print(f"Thời gian xử lý trung bình mỗi ảnh (Classification): {avg_inference_time:.4f} giây")
    print(f"Tổng thời gian xử lý: {total_inference_time:.4f} giây")
    print(f"Accuracy (tổng thể): {accuracy:.4f}")
    print(f"F1 Score (Macro, trên các lớp chính {f1_labels_strict}): {f1_macro:.4f}")
    print(f"F1 Score (Weighted, trên các lớp chính {f1_labels_strict}): {f1_weighted:.4f}")
    
    print("\nConfusion Matrix (Tổng thể):")
    cm_df = pd.DataFrame(cm, index=cm_labels_ordered, columns=cm_labels_ordered)
    print(cm_df)

    print(f"\nClassification Report (trên các lớp {meaningful_labels_for_report}):")
    print(report_str)

    results_summary_path = output_dir_path / "evaluation_summary_mobilenet_precropped.txt"
    with open(results_summary_path, "w", encoding="utf-8") as f:
        f.write("--- KẾT QUẢ ĐÁNH GIÁ MODEL MOBILENETV2 (trên ảnh đã crop sẵn) ---\n")
        f.write(f"Model Path: {MODEL_PATH}\n")
        f.write(f"CSV Path: {CSV_PATH}\n")
        f.write(f"Input Shape (của ảnh đã crop): {INPUT_SHAPE}\n")
        f.write(f"Class Labels (Model): {CLASS_LABELS}\n")
        f.write(f"Thư mục ảnh đã xử lý: {processed_images_path}\n")
        f.write(f"Số lượng ảnh đã xử lý: {len(true_labels_list)}\n")
        f.write(f"Thời gian xử lý trung bình mỗi ảnh: {avg_inference_time:.4f} giây\n")
        f.write(f"Tổng thời gian xử lý: {total_inference_time:.4f} giây\n")
        f.write(f"Accuracy (tổng thể): {accuracy:.4f}\n")
        f.write(f"F1 Score (Macro, trên các lớp chính {f1_labels_strict}): {f1_macro:.4f}\n")
        f.write(f"F1 Score (Weighted, trên các lớp chính {f1_labels_strict}): {f1_weighted:.4f}\n\n")
        f.write("Confusion Matrix (Tổng thể):\n")
        f.write(cm_df.to_string() + "\n\n")
        f.write(f"Classification Report (trên các lớp {meaningful_labels_for_report}):\n")
        f.write(report_str + "\n")
    print(f"\nKết quả tóm tắt đã được lưu vào: {results_summary_path}")

    cm_plot_path = output_dir_path / "confusion_matrix_mobilenet_precropped.png"
    plot_confusion_matrix(cm, classes=cm_labels_ordered, title='Confusion Matrix of MobileNetV2', output_path=str(cm_plot_path))

    cm_norm_plot_path = output_dir_path / "confusion_matrix_mobilenet_precropped_normalized.png"
    plot_confusion_matrix(cm, classes=cm_labels_ordered, normalize=True, title='Confusion Matrix of MobileNetV2', output_path=str(cm_norm_plot_path))

    print(f"\nĐã hoàn thành. Kết quả và ảnh đã xử lý được lưu trong thư mục '{output_dir_path}'.")

if __name__ == '__main__':
    # Không cần kiểm tra MediaPipe nữa
    if 'cv2' not in globals() or 'load_model' not in globals():
        print("Lỗi: Thiếu thư viện OpenCV hoặc TensorFlow/Keras.")
        print("Vui lòng cài đặt: pip install opencv-python tensorflow pandas scikit-learn matplotlib seaborn")

    else:
        main()
# Out:
# Loading classification model from: model/mobilenet-v2.h5
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Classification model loaded successfully.
# Loading CSV from: output1.csv
#
# Bắt đầu dự đoán trên 156 ảnh (đã crop sẵn). Ảnh đã xử lý sẽ được lưu vào 'mobilenetv2_precropped_evaluation_output_with_images1\processed_images'
# Ảnh: 20250307_222838_031.jpg - True: look_away, Predicted: look_away (Time: 1.2783s)
# Ảnh: 20250307_222838_032.jpg - True: look_away, Predicted: look_away (Time: 0.1202s)
# Ảnh: 20250307_222838_033.jpg - True: look_away, Predicted: look_away (Time: 0.1168s)
# Ảnh: 20250307_222838_034.jpg - True: look_away, Predicted: look_away (Time: 0.1028s)
# Ảnh: 20250307_222838_035.jpg - True: look_away, Predicted: look_away (Time: 0.0996s)
# Ảnh: 20250307_222838_036.jpg - True: look_away, Predicted: look_away (Time: 0.1037s)
# Ảnh: 20250307_222838_037.jpg - True: look_away, Predicted: look_away (Time: 0.0981s)
# Ảnh: 20250307_222838_039.jpg - True: look_away, Predicted: look_away (Time: 0.0960s)
# Ảnh: 20250307_222838_040.jpg - True: look_away, Predicted: look_away (Time: 0.1097s)
# Ảnh: 20250307_222838_041.jpg - True: look_away, Predicted: look_away (Time: 0.0958s)
# Ảnh: 20250307_222838_042.jpg - True: look_away, Predicted: look_away (Time: 0.0969s)
# Ảnh: 20250307_222838_043.jpg - True: look_away, Predicted: look_away (Time: 0.1156s)
# Ảnh: 20250307_222838_044.jpg - True: look_away, Predicted: look_away (Time: 0.1173s)
# Ảnh: 20250307_222838_045.jpg - True: look_away, Predicted: look_away (Time: 0.1234s)
# Ảnh: 20250307_222838_047.jpg - True: look_away, Predicted: look_away (Time: 0.1165s)
# Ảnh: 20250307_222838_048.jpg - True: look_away, Predicted: look_away (Time: 0.1157s)
# Ảnh: 20250307_222838_049.jpg - True: look_away, Predicted: look_away (Time: 0.0990s)
# Ảnh: 20250307_222838_050.jpg - True: look_away, Predicted: look_away (Time: 0.1132s)
# Ảnh: 20250307_222838_051.jpg - True: look_away, Predicted: look_away (Time: 0.1342s)
# Ảnh: 20250307_222838_052.jpg - True: look_away, Predicted: look_away (Time: 0.1004s)
# Ảnh: 20250307_222838_053.jpg - True: look_away, Predicted: look_away (Time: 0.0989s)
# Ảnh: 20250307_222838_054.jpg - True: look_away, Predicted: look_away (Time: 0.0952s)
# Ảnh: 20250307_222838_055.jpg - True: look_away, Predicted: look_away (Time: 0.0992s)
# Ảnh: 20250307_222838_056.jpg - True: look_away, Predicted: look_away (Time: 0.2138s)
# Ảnh: 20250307_222838_057.jpg - True: look_away, Predicted: look_away (Time: 0.1039s)
# Ảnh: 20250307_222838_058.jpg - True: look_away, Predicted: look_away (Time: 0.1131s)
# Ảnh: 20250307_222838_059.jpg - True: look_away, Predicted: look_away (Time: 0.0940s)
# Ảnh: 20250307_222838_060.jpg - True: look_away, Predicted: look_away (Time: 0.1266s)
# Ảnh: 20250307_222838_061.jpg - True: look_away, Predicted: look_away (Time: 0.1649s)
# Ảnh: 20250307_222838_062.jpg - True: look_away, Predicted: look_away (Time: 0.1550s)
# Ảnh: 10.jpg - True: natural, Predicted: natural (Time: 0.1418s)
# Ảnh: 11.jpg - True: natural, Predicted: natural (Time: 0.1786s)
# Ảnh: 12.jpg - True: natural, Predicted: natural (Time: 0.1169s)
# Ảnh: 13.jpg - True: natural, Predicted: natural (Time: 0.1342s)
# Ảnh: 14.jpg - True: natural, Predicted: natural (Time: 0.1899s)
# Ảnh: 19.jpg - True: natural, Predicted: natural (Time: 0.1325s)
# Ảnh: 20.jpg - True: natural, Predicted: natural (Time: 0.1096s)
# Ảnh: 20250307_232312_210.jpg - True: natural, Predicted: natural (Time: 0.1011s)
# Ảnh: 20250307_232312_211.jpg - True: natural, Predicted: natural (Time: 0.1015s)
# Ảnh: 20250307_232312_244.jpg - True: natural, Predicted: natural (Time: 0.1431s)
# Ảnh: 20250307_232312_245.jpg - True: natural, Predicted: natural (Time: 0.0881s)
# Ảnh: 20250307_232312_246.jpg - True: natural, Predicted: natural (Time: 0.0839s)
# Ảnh: 20250307_232312_247.jpg - True: natural, Predicted: natural (Time: 0.0805s)
# Ảnh: 20250307_232312_248.jpg - True: natural, Predicted: natural (Time: 0.0733s)
# Ảnh: 20250307_232312_250.jpg - True: natural, Predicted: natural (Time: 0.0895s)
# Ảnh: 21.jpg - True: natural, Predicted: natural (Time: 0.0934s)
# Ảnh: 22.jpg - True: natural, Predicted: natural (Time: 0.1121s)
# Ảnh: 23.jpg - True: natural, Predicted: natural (Time: 0.0797s)
# Ảnh: 24.jpg - True: natural, Predicted: natural (Time: 0.0891s)
# Ảnh: 25.jpg - True: natural, Predicted: natural (Time: 0.0887s)
# Ảnh: 26.jpg - True: natural, Predicted: natural (Time: 0.0900s)
# Ảnh: 27.jpg - True: natural, Predicted: natural (Time: 0.0888s)
# Ảnh: 28.jpg - True: natural, Predicted: natural (Time: 0.0999s)
# Ảnh: 29.jpg - True: natural, Predicted: natural (Time: 0.1150s)
# Ảnh: 30.jpg - True: natural, Predicted: natural (Time: 0.0903s)
# Ảnh: 31.jpg - True: natural, Predicted: natural (Time: 0.0851s)
# Ảnh: 32.jpg - True: natural, Predicted: natural (Time: 0.1073s)
# Ảnh: 33.jpg - True: natural, Predicted: natural (Time: 0.1071s)
# Ảnh: 34.jpg - True: natural, Predicted: natural (Time: 0.1121s)
# Ảnh: 35.jpg - True: natural, Predicted: natural (Time: 0.0897s)
# Ảnh: 36.jpg - True: natural, Predicted: natural (Time: 0.0824s)
# Ảnh: 37.jpg - True: natural, Predicted: natural (Time: 0.0797s)
# Ảnh: 38.jpg - True: natural, Predicted: natural (Time: 0.0879s)
# Ảnh: 5.jpg - True: natural, Predicted: natural (Time: 0.0813s)
# Ảnh: 6.jpg - True: natural, Predicted: natural (Time: 0.0796s)
# Ảnh: 7.jpg - True: natural, Predicted: natural (Time: 0.1014s)
# Ảnh: 8.jpg - True: natural, Predicted: natural (Time: 0.1004s)
# Ảnh: 9.jpg - True: natural, Predicted: natural (Time: 0.0865s)
# Ảnh: 20250307_232312_189.jpg - True: rub_eye, Predicted: rub_eye (Time: 0.0999s)
# Ảnh: WIN_20250522_21_47_36_Pro_005.jpg - True: rub_eye, Predicted: rub_eye (Time: 0.0844s)
# Ảnh: WIN_20250522_21_47_36_Pro_017.jpg - True: rub_eye, Predicted: rub_eye (Time: 0.0855s)
# Ảnh: WIN_20250522_21_47_36_Pro_020.jpg - True: rub_eye, Predicted: rub_eye (Time: 0.0981s)
# Ảnh: WIN_20250522_21_47_36_Pro_024.jpg - True: rub_eye, Predicted: rub_eye (Time: 0.0838s)
# Ảnh: 115.jpg - True: natural, Predicted: natural (Time: 0.1043s)
# Ảnh: 116.jpg - True: natural, Predicted: natural (Time: 0.0867s)
# Ảnh: 117.jpg - True: natural, Predicted: natural (Time: 0.0851s)
# Ảnh: 118.jpg - True: natural, Predicted: natural (Time: 0.0833s)
# Ảnh: 15.jpg - True: natural, Predicted: natural (Time: 0.0816s)
# Ảnh: 16.jpg - True: natural, Predicted: natural (Time: 0.1147s)
# Ảnh: 174.jpg - True: sleepy_eye, Predicted: natural (Time: 0.0858s)
# Ảnh: 175.jpg - True: sleepy_eye, Predicted: natural (Time: 0.1162s)
# Ảnh: 176.jpg - True: sleepy_eye, Predicted: natural (Time: 0.0994s)
# Ảnh: 177.jpg - True: sleepy_eye, Predicted: natural (Time: 0.1174s)
# Ảnh: 178.jpg - True: sleepy_eye, Predicted: natural (Time: 0.1124s)
# Ảnh: 179.jpg - True: sleepy_eye, Predicted: natural (Time: 0.0929s)
# Ảnh: 180.jpg - True: sleepy_eye, Predicted: sleepy_eye (Time: 0.1369s)
# Ảnh: 181.jpg - True: sleepy_eye, Predicted: sleepy_eye (Time: 0.1490s)
# Ảnh: 182.jpg - True: natural, Predicted: natural (Time: 0.0917s)
# Ảnh: 183.jpg - True: natural, Predicted: natural (Time: 0.0950s)
# Ảnh: 20250307_232312_242.jpg - True: sleepy_eye, Predicted: look_away (Time: 0.0955s)
# Ảnh: 20250321_221026_119.jpg - True: sleepy_eye, Predicted: sleepy_eye (Time: 0.0870s)
# Ảnh: 3459.jpg - True: sleepy_eye, Predicted: yawn (Time: 0.0818s)
# Ảnh: 3460.jpg - True: sleepy_eye, Predicted: yawn (Time: 0.1033s)
# Ảnh: 3461.jpg - True: sleepy_eye, Predicted: yawn (Time: 0.1103s)
# Ảnh: 3462.jpg - True: sleepy_eye, Predicted: yawn (Time: 0.0963s)
# Ảnh: 3463.jpg - True: sleepy_eye, Predicted: yawn (Time: 0.0911s)
# Ảnh: 3464.jpg - True: sleepy_eye, Predicted: yawn (Time: 0.0930s)
# Ảnh: 3465.jpg - True: natural, Predicted: natural (Time: 0.0876s)
# Ảnh: 3466.jpg - True: natural, Predicted: natural (Time: 0.0865s)
# Ảnh: 3467.jpg - True: natural, Predicted: yawn (Time: 0.0848s)
# Ảnh: 3468.jpg - True: natural, Predicted: yawn (Time: 0.0888s)
# Ảnh: 3469.jpg - True: natural, Predicted: yawn (Time: 0.0720s)
# Ảnh: 3470.jpg - True: natural, Predicted: natural (Time: 0.0782s)
# Ảnh: 3471.jpg - True: natural, Predicted: natural (Time: 0.0828s)
# Ảnh: 3472.jpg - True: natural, Predicted: natural (Time: 0.0741s)
# Ảnh: 3473.jpg - True: natural, Predicted: natural (Time: 0.0775s)
# Ảnh: 3474.jpg - True: sleepy_eye, Predicted: natural (Time: 0.0959s)
# Ảnh: 3475.jpg - True: sleepy_eye, Predicted: natural (Time: 0.0946s)
# Ảnh: 3476.jpg - True: sleepy_eye, Predicted: natural (Time: 0.1031s)
# Ảnh: 3477.jpg - True: sleepy_eye, Predicted: natural (Time: 0.0932s)
# Ảnh: 3478.jpg - True: sleepy_eye, Predicted: natural (Time: 0.0811s)
# Ảnh: 3479.jpg - True: sleepy_eye, Predicted: natural (Time: 0.0741s)
# Ảnh: 3480.jpg - True: sleepy_eye, Predicted: sleepy_eye (Time: 0.0844s)
# Ảnh: 40.jpg - True: natural, Predicted: natural (Time: 0.0872s)
# Ảnh: 83.jpg - True: natural, Predicted: natural (Time: 0.0941s)
# Ảnh: WIN_20250522_21_47_36_Pro_098.jpg - True: sleepy_eye, Predicted: sleepy_eye (Time: 0.0935s)
# Ảnh: 1310.jpg - True: yawn, Predicted: yawn (Time: 0.0906s)
# Ảnh: 1314.jpg - True: yawn, Predicted: yawn (Time: 0.0857s)
# Ảnh: 1327.jpg - True: yawn, Predicted: yawn (Time: 0.0769s)
# Ảnh: 1347.jpg - True: yawn, Predicted: yawn (Time: 0.0809s)
# Ảnh: 3210.jpg - True: yawn, Predicted: natural (Time: 0.0813s)
# Ảnh: 3218.jpg - True: yawn, Predicted: yawn (Time: 0.0746s)
# Ảnh: 3228.jpg - True: yawn, Predicted: yawn (Time: 0.0860s)
# Ảnh: 3710.jpg - True: yawn, Predicted: yawn (Time: 0.0801s)
# Ảnh: 3716.jpg - True: yawn, Predicted: yawn (Time: 0.0898s)
# Ảnh: 446.jpg - True: yawn, Predicted: yawn (Time: 0.0862s)
# Ảnh: 447.jpg - True: yawn, Predicted: yawn (Time: 0.0879s)
# Ảnh: 448.jpg - True: natural, Predicted: natural (Time: 0.0829s)
# Ảnh: 449.jpg - True: natural, Predicted: natural (Time: 0.0813s)
# Ảnh: 450.jpg - True: natural, Predicted: natural (Time: 0.1444s)
# Ảnh: 451.jpg - True: natural, Predicted: natural (Time: 0.1064s)
# Ảnh: 452.jpg - True: natural, Predicted: natural (Time: 0.0930s)
# Ảnh: 453.jpg - True: yawn, Predicted: yawn (Time: 0.0858s)
# Ảnh: 454.jpg - True: yawn, Predicted: yawn (Time: 0.0791s)
# Ảnh: 455.jpg - True: natural, Predicted: natural (Time: 0.0935s)
# Ảnh: 456.jpg - True: natural, Predicted: natural (Time: 0.0843s)
# Ảnh: 457.jpg - True: yawn, Predicted: yawn (Time: 0.0792s)
# Ảnh: 458.jpg - True: yawn, Predicted: yawn (Time: 0.0892s)
# Ảnh: 459.jpg - True: yawn, Predicted: yawn (Time: 0.0990s)
# Ảnh: 460.jpg - True: yawn, Predicted: yawn (Time: 0.0787s)
# Ảnh: 461.jpg - True: yawn, Predicted: yawn (Time: 0.0890s)
# Ảnh: 462.jpg - True: yawn, Predicted: yawn (Time: 0.1011s)
# Ảnh: 463.jpg - True: yawn, Predicted: yawn (Time: 0.0911s)
# Ảnh: 464.jpg - True: yawn, Predicted: yawn (Time: 0.1001s)
# Ảnh: 465.jpg - True: yawn, Predicted: yawn (Time: 0.0848s)
# Ảnh: 466.jpg - True: yawn, Predicted: yawn (Time: 0.1041s)
# Ảnh: 467.jpg - True: yawn, Predicted: yawn (Time: 0.1203s)
# Ảnh: 468.jpg - True: yawn, Predicted: yawn (Time: 0.0958s)
# Ảnh: 469.jpg - True: yawn, Predicted: yawn (Time: 0.1259s)
# Ảnh: 470.jpg - True: yawn, Predicted: yawn (Time: 0.1119s)
# Ảnh: 471.jpg - True: yawn, Predicted: yawn (Time: 0.1303s)
# Ảnh: 472.jpg - True: yawn, Predicted: yawn (Time: 0.1031s)
# Ảnh: 473.jpg - True: yawn, Predicted: yawn (Time: 0.1085s)
# Ảnh: 474.jpg - True: yawn, Predicted: yawn (Time: 0.1401s)
# Ảnh: 475.jpg - True: yawn, Predicted: yawn (Time: 0.1344s)
# Ảnh: 487.jpg - True: yawn, Predicted: yawn (Time: 0.1068s)
#
# --- KẾT QUẢ ĐÁNH GIÁ (MobileNetV2 trên ảnh đã crop sẵn) ---
# Số lượng ảnh đã xử lý: 156
# Thời gian xử lý trung bình mỗi ảnh (Classification): 0.1083 giây
# Tổng thời gian xử lý: 16.8899 giây
# Accuracy (tổng thể): 0.8526
# F1 Score (Macro, trên các lớp chính ['look_away', 'natural', 'rub_eye', 'sleepy_eye', 'yawn']): 0.8155
# F1 Score (Weighted, trên các lớp chính ['look_away', 'natural', 'rub_eye', 'sleepy_eye', 'yawn']): 0.8199
#
# Confusion Matrix (Tổng thể):
#             look_away  natural  rub_eye  sleepy_eye  yawn
# look_away          30        0        0           0     0
# natural             0       61        0           0     3
# rub_eye             0        0        5           0     0
# sleepy_eye          1       12        0           5     6
# yawn                0        1        0           0    32
#
# Classification Report (trên các lớp ['look_away', 'natural', 'rub_eye', 'sleepy_eye', 'yawn']):
#               precision    recall  f1-score   support
#
#    look_away       0.97      1.00      0.98        30
#      natural       0.82      0.95      0.88        64
#      rub_eye       1.00      1.00      1.00         5
#   sleepy_eye       1.00      0.21      0.34        24
#         yawn       0.78      0.97      0.86        33
#
#     accuracy                           0.85       156
#    macro avg       0.91      0.83      0.82       156
# weighted avg       0.88      0.85      0.82       156
#
#
# Kết quả tóm tắt đã được lưu vào: mobilenetv2_precropped_evaluation_output_with_images1\evaluation_summary_mobilenet_precropped.txt
# Confusion matrix saved to mobilenetv2_precropped_evaluation_output_with_images1\confusion_matrix_mobilenet_precropped.png
# Confusion matrix saved to mobilenetv2_precropped_evaluation_output_with_images1\confusion_matrix_mobilenet_precropped_normalized.png
#
# Đã hoàn thành. Kết quả và ảnh đã xử lý được lưu trong thư mục 'mobilenetv2_precropped_evaluation_output_with_images1'.

# %% [markdown]
# ## CNN

# %%
import pandas as pd
import time
import os
from pathlib import Path
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, f1_score
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import cv2
from tensorflow.keras.models import load_model

# --- CẤU HÌNH ---
MODEL_PATH = "model/custom_cnn_sleepiness_model.h5"
CSV_PATH = "output.csv" # File CSV chứa đường dẫn đến các ảnh ĐÃ ĐƯỢC CROP
IMAGE_BASE_DIR = "" # Để trống nếu đường dẫn trong CSV là tuyệt đối hoặc tương đối với thư mục script
OUTPUT_DIR = "cnn_precropped_evaluation_output_with_images1"
PROCESSED_IMAGES_SUBDIR = "processed_images" # Thư mục con để lưu ảnh đã vẽ
INPUT_SHAPE = (224, 224) # Kích thước đầu vào mà model CNN mong đợi

CLASS_LABELS = ['natural', 'sleepy_eye', 'yawn', 'rub_eye', 'look_away']

# --- HÀM HỖ TRỢ ---
def preprocess_image_for_mobilenet(image_bgr, target_size=(224, 224)):
    """
    Tiền xử lý ảnh (đã crop) cho CNN.
    Input là ảnh BGR đọc từ cv2.imread.
    """
    if image_bgr is None or image_bgr.size == 0:
        print("Lỗi: Ảnh đầu vào cho tiền xử lý rỗng hoặc không hợp lệ.")
        return None
    
    # CNN thường được huấn luyện với ảnh RGB
    image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)
    image_resized = cv2.resize(image_rgb, target_size)
    image_normalized = image_resized / 255.0
    image_normalized = image_normalized.astype(np.float32)
    image_batch = np.expand_dims(image_normalized, axis=0) # Thêm batch dimension
    return image_batch

def get_predicted_label_mobilenet(probabilities, class_labels_ordered):
    """
    Trích xuất nhãn dự đoán từ vector xác suất của CNN.
    Chọn nhãn có xác suất cao nhất.
    """
    
    highest_prob_idx = np.argmax(probabilities)
    predicted_label_str = class_labels_ordered[highest_prob_idx]
    return predicted_label_str

def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues, output_path="confusion_matrix.png"):
    if normalize:
        # Tránh chia cho 0 nếu một hàng toàn là 0 (không có mẫu nào của lớp đó)
        cm_sum = cm.sum(axis=1)[:, np.newaxis]
        with np.errstate(divide='ignore', invalid='ignore'):
            cm_normalized = np.where(cm_sum > 0, cm.astype('float') / cm_sum, 0)
        cm = cm_normalized # Gán lại cm sau khi chuẩn hóa an toàn
        
    plt.figure(figsize=(max(8, int(len(classes)*0.8) ), max(6, int(len(classes) * 0.6))))
    sns.heatmap(cm, annot=True, fmt=".2f" if normalize else "d", cmap=cmap, xticklabels=classes, yticklabels=classes)
    plt.title(title)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.savefig(output_path)
    print(f"Confusion matrix saved to {output_path}")

# --- CHƯƠNG TRÌNH CHÍNH ---
def main():
    output_dir_path = Path(OUTPUT_DIR)
    processed_images_path = output_dir_path / PROCESSED_IMAGES_SUBDIR
    output_dir_path.mkdir(parents=True, exist_ok=True)
    processed_images_path.mkdir(parents=True, exist_ok=True)

    print(f"Loading classification model from: {MODEL_PATH}")
    if not os.path.exists(MODEL_PATH):
        print(f"LỖI: Model phân loại không tìm thấy tại: {MODEL_PATH}")
        return
    try:
        classification_model = load_model(MODEL_PATH)
        print("Classification model loaded successfully.")
    except Exception as e:
        print(f"LỖI: Không thể tải model phân loại: {e}")
        return

    print(f"Loading CSV from: {CSV_PATH}")
    if not os.path.exists(CSV_PATH):
        print(f"LỖI: CSV file không tìm thấy tại: {CSV_PATH}")
        return
    df = pd.read_csv(CSV_PATH)

    true_labels_list = []
    predicted_labels_list = []
    inference_times_total = []

    print(f"\nBắt đầu dự đoán trên {len(df)} ảnh (đã crop sẵn). Ảnh đã xử lý sẽ được lưu vào '{processed_images_path}'")

    for index, row in df.iterrows():
        image_path_relative = row['original_file_path']
        true_label = row['labels'] # Nhãn thật từ CSV
        image_filename = Path(image_path_relative).name

        # Xử lý đường dẫn ảnh
        if IMAGE_BASE_DIR:
            base = Path(IMAGE_BASE_DIR)
            if not base.is_absolute(): base = Path.cwd() / base
            image_path_full_obj = base / image_path_relative
        else:
            image_path_full_obj = Path(image_path_relative)
            if not image_path_full_obj.is_absolute(): image_path_full_obj = Path.cwd() / image_path_full_obj
        image_path_full = str(image_path_full_obj.resolve())

        # Đọc ảnh (đã được crop)
        cropped_image_from_file = cv2.imread(image_path_full)
        
        predicted_label_for_image = ""
        output_image_to_save = None

        if cropped_image_from_file is None:
            print(f"CẢNH BÁO: Ảnh (đã crop) không tải được: {image_path_full}. Bỏ qua.")
            continue
        
        output_image_to_save = cropped_image_from_file.copy() # Ảnh này đã được crop
        start_time_total = time.time()

        # Tiền xử lý ảnh đã crop
        image_batch = preprocess_image_for_mobilenet(cropped_image_from_file, target_size=INPUT_SHAPE)
        
        if image_batch is not None:
            try:
                # Dự đoán bằng CNN
                predictions_proba = classification_model.predict(image_batch, verbose=0)[0]
                predicted_label_for_image = get_predicted_label_mobilenet(predictions_proba, CLASS_LABELS)
            except Exception as e:
                print(f"Lỗi khi dự đoán ảnh {image_filename} bằng model: {e}")
        else:
            print(f"Lỗi tiền xử lý ảnh (đã crop) cho: {image_filename}")

        end_time_total = time.time()
        inference_times_total.append(end_time_total - start_time_total)

        true_labels_list.append(true_label)
        predicted_labels_list.append(predicted_label_for_image)

        # Vẽ thông tin lên ảnh (đã crop)
        text_to_draw = f"Pred: {predicted_label_for_image}"
        true_text_to_draw = f"True: {true_label}"
        
        text_color = (0, 255, 0) # Xanh lá cho dự đoán đúng

        # Vì ảnh đã crop, vị trí vẽ text có thể cần điều chỉnh
        text_y_position = 30
        if output_image_to_save.shape[0] < 60: # Nếu ảnh quá nhỏ
            text_y_position = output_image_to_save.shape[0] // 4

        cv2.putText(output_image_to_save, text_to_draw, (10, text_y_position), 
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, text_color, 2)
        cv2.putText(output_image_to_save, true_text_to_draw, (10, output_image_to_save.shape[0] - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 0, 0), 2) # Xanh dương cho nhãn thật

        # Lưu ảnh đã vẽ
        save_path = processed_images_path / image_filename
        try:
            cv2.imwrite(str(save_path), output_image_to_save)
        except Exception as e:
            print(f"Lỗi khi lưu ảnh {save_path}: {e}")

        print(f"Ảnh: {image_filename} - True: {true_label}, Predicted: {predicted_label_for_image} (Time: {end_time_total - start_time_total:.4f}s)")

    # 3. Tính toán và lưu trữ kết quả
    if not true_labels_list or not predicted_labels_list:
        print("Không có dự đoán nào được thực hiện. Kết thúc.")
        return

    print("\n--- KẾT QUẢ ĐÁNH GIÁ (CNN trên ảnh đã crop sẵn) ---")

    # Bao gồm tất cả các nhãn từ CSV, model và các nhãn lỗi có thể có
    cm_labels_ordered = sorted(list(set(true_labels_list + predicted_labels_list + CLASS_LABELS)))
    
    cm = confusion_matrix(true_labels_list, predicted_labels_list, labels=cm_labels_ordered)
    accuracy = accuracy_score(true_labels_list, predicted_labels_list)
    
    # Labels để báo cáo chi tiết (thường là các lớp model được huấn luyện)
    meaningful_labels_for_report = sorted(list(set(CLASS_LABELS).intersection(set(cm_labels_ordered))))
    
    if not meaningful_labels_for_report: # Nếu không có nhãn nào chung để báo cáo
        report_str = "Không có lớp chung giữa nhãn thật và dự đoán trong CLASS_LABELS để tạo báo cáo."
        print(report_str)
    else:
        report_str = classification_report(true_labels_list, predicted_labels_list, labels=meaningful_labels_for_report, zero_division=0, target_names=meaningful_labels_for_report)
    
    # Labels để tính F1 (chỉ các lớp chính, không tính lỗi)
    f1_labels_strict = meaningful_labels_for_report[:] # Sử dụng các nhãn đã lọc ở trên
    
    if not f1_labels_strict:
        f1_macro = 0.0
        f1_weighted = 0.0
        print("Cảnh báo: Không có nhãn phù hợp để tính F1 score chi tiết.")
    else:
        f1_macro = f1_score(true_labels_list, predicted_labels_list, average='macro', labels=f1_labels_strict, zero_division=0)
        f1_weighted = f1_score(true_labels_list, predicted_labels_list, average='weighted', labels=f1_labels_strict, zero_division=0)

    avg_inference_time = sum(inference_times_total) / len(inference_times_total) if inference_times_total else 0
    total_inference_time = sum(inference_times_total)

    print(f"Số lượng ảnh đã xử lý: {len(true_labels_list)}")
    print(f"Thời gian xử lý trung bình mỗi ảnh (Classification): {avg_inference_time:.4f} giây")
    print(f"Tổng thời gian xử lý: {total_inference_time:.4f} giây")
    print(f"Accuracy (tổng thể): {accuracy:.4f}")
    print(f"F1 Score (Macro, trên các lớp chính {f1_labels_strict}): {f1_macro:.4f}")
    print(f"F1 Score (Weighted, trên các lớp chính {f1_labels_strict}): {f1_weighted:.4f}")
    
    print("\nConfusion Matrix (Tổng thể):")
    cm_df = pd.DataFrame(cm, index=cm_labels_ordered, columns=cm_labels_ordered)
    print(cm_df)

    print(f"\nClassification Report (trên các lớp {meaningful_labels_for_report}):")
    print(report_str)

    results_summary_path = output_dir_path / "evaluation_summary_mobilenet_precropped.txt"
    with open(results_summary_path, "w", encoding="utf-8") as f:
        f.write("--- KẾT QUẢ ĐÁNH GIÁ MODEL CNN (trên ảnh đã crop sẵn) ---\n")
        f.write(f"Model Path: {MODEL_PATH}\n")
        f.write(f"CSV Path: {CSV_PATH}\n")
        f.write(f"Input Shape (của ảnh đã crop): {INPUT_SHAPE}\n")
        f.write(f"Class Labels (Model): {CLASS_LABELS}\n")
        f.write(f"Thư mục ảnh đã xử lý: {processed_images_path}\n")
        f.write(f"Số lượng ảnh đã xử lý: {len(true_labels_list)}\n")
        f.write(f"Thời gian xử lý trung bình mỗi ảnh: {avg_inference_time:.4f} giây\n")
        f.write(f"Tổng thời gian xử lý: {total_inference_time:.4f} giây\n")
        f.write(f"Accuracy (tổng thể): {accuracy:.4f}\n")
        f.write(f"F1 Score (Macro, trên các lớp chính {f1_labels_strict}): {f1_macro:.4f}\n")
        f.write(f"F1 Score (Weighted, trên các lớp chính {f1_labels_strict}): {f1_weighted:.4f}\n\n")
        f.write("Confusion Matrix (Tổng thể):\n")
        f.write(cm_df.to_string() + "\n\n")
        f.write(f"Classification Report (trên các lớp {meaningful_labels_for_report}):\n")
        f.write(report_str + "\n")
    print(f"\nKết quả tóm tắt đã được lưu vào: {results_summary_path}")

    cm_plot_path = output_dir_path / "confusion_matrix_mobilenet_precropped.png"
    plot_confusion_matrix(cm, classes=cm_labels_ordered, title='Confusion Matrix of CNN', output_path=str(cm_plot_path))

    cm_norm_plot_path = output_dir_path / "confusion_matrix_mobilenet_precropped_normalized.png"
    plot_confusion_matrix(cm, classes=cm_labels_ordered, normalize=True, title='Confusion Matrix of CNN', output_path=str(cm_norm_plot_path))

    print(f"\nĐã hoàn thành. Kết quả và ảnh đã xử lý được lưu trong thư mục '{output_dir_path}'.")

if __name__ == '__main__':
    # Không cần kiểm tra MediaPipe nữa
    if 'cv2' not in globals() or 'load_model' not in globals():
        print("Lỗi: Thiếu thư viện OpenCV hoặc TensorFlow/Keras.")
        print("Vui lòng cài đặt: pip install opencv-python tensorflow pandas scikit-learn matplotlib seaborn")

    else:
        main()
# Out:
# Loading classification model from: model/custom_cnn_sleepiness_model.h5
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Classification model loaded successfully.
# Loading CSV from: output.csv
#
# Bắt đầu dự đoán trên 156 ảnh (đã crop sẵn). Ảnh đã xử lý sẽ được lưu vào 'cnn_precropped_evaluation_output_with_images1\processed_images'
# Ảnh: 20250307_222838_031.jpg - True: look_away, Predicted: look_away (Time: 0.2424s)
# Ảnh: 20250307_222838_032.jpg - True: look_away, Predicted: look_away (Time: 0.1002s)
# Ảnh: 20250307_222838_033.jpg - True: look_away, Predicted: look_away (Time: 0.0923s)
# Ảnh: 20250307_222838_034.jpg - True: look_away, Predicted: look_away (Time: 0.0978s)
# Ảnh: 20250307_222838_035.jpg - True: look_away, Predicted: look_away (Time: 0.0960s)
# Ảnh: 20250307_222838_036.jpg - True: look_away, Predicted: look_away (Time: 0.1061s)
# Ảnh: 20250307_222838_037.jpg - True: look_away, Predicted: look_away (Time: 0.0985s)
# Ảnh: 20250307_222838_039.jpg - True: look_away, Predicted: look_away (Time: 0.2936s)
# Ảnh: 20250307_222838_040.jpg - True: look_away, Predicted: look_away (Time: 0.1655s)
# Ảnh: 20250307_222838_041.jpg - True: look_away, Predicted: look_away (Time: 0.1651s)
# Ảnh: 20250307_222838_042.jpg - True: look_away, Predicted: look_away (Time: 0.1358s)
# Ảnh: 20250307_222838_043.jpg - True: look_away, Predicted: look_away (Time: 0.0910s)
# Ảnh: 20250307_222838_044.jpg - True: look_away, Predicted: look_away (Time: 0.0930s)
# Ảnh: 20250307_222838_045.jpg - True: look_away, Predicted: look_away (Time: 0.0962s)
# Ảnh: 20250307_222838_047.jpg - True: look_away, Predicted: look_away (Time: 0.1462s)
# Ảnh: 20250307_222838_048.jpg - True: look_away, Predicted: look_away (Time: 0.1318s)
# Ảnh: 20250307_222838_049.jpg - True: look_away, Predicted: look_away (Time: 0.1126s)
# Ảnh: 20250307_222838_050.jpg - True: look_away, Predicted: look_away (Time: 0.1102s)
# Ảnh: 20250307_222838_051.jpg - True: look_away, Predicted: look_away (Time: 0.1167s)
# Ảnh: 20250307_222838_052.jpg - True: look_away, Predicted: look_away (Time: 0.0845s)
# Ảnh: 20250307_222838_053.jpg - True: look_away, Predicted: look_away (Time: 0.0876s)
# Ảnh: 20250307_222838_054.jpg - True: look_away, Predicted: look_away (Time: 0.0990s)
# Ảnh: 20250307_222838_055.jpg - True: look_away, Predicted: look_away (Time: 0.0852s)
# Ảnh: 20250307_222838_056.jpg - True: look_away, Predicted: look_away (Time: 0.0855s)
# Ảnh: 20250307_222838_057.jpg - True: look_away, Predicted: look_away (Time: 0.0882s)
# Ảnh: 20250307_222838_058.jpg - True: look_away, Predicted: look_away (Time: 0.0829s)
# Ảnh: 20250307_222838_059.jpg - True: look_away, Predicted: look_away (Time: 0.0980s)
# Ảnh: 20250307_222838_060.jpg - True: look_away, Predicted: look_away (Time: 0.0977s)
# Ảnh: 20250307_222838_061.jpg - True: look_away, Predicted: look_away (Time: 0.1326s)
# Ảnh: 20250307_222838_062.jpg - True: look_away, Predicted: look_away (Time: 0.1404s)
# Ảnh: 10.jpg - True: natural, Predicted: look_away (Time: 0.0941s)
# Ảnh: 11.jpg - True: natural, Predicted: look_away (Time: 0.1004s)
# Ảnh: 12.jpg - True: natural, Predicted: look_away (Time: 0.1050s)
# Ảnh: 13.jpg - True: natural, Predicted: look_away (Time: 0.1231s)
# Ảnh: 14.jpg - True: natural, Predicted: look_away (Time: 0.1216s)
# Ảnh: 19.jpg - True: natural, Predicted: look_away (Time: 0.0858s)
# Ảnh: 20.jpg - True: natural, Predicted: look_away (Time: 0.0865s)
# Ảnh: 20250307_232312_210.jpg - True: natural, Predicted: rub_eye (Time: 0.0875s)
# Ảnh: 20250307_232312_211.jpg - True: natural, Predicted: rub_eye (Time: 0.0769s)
# Ảnh: 20250307_232312_244.jpg - True: natural, Predicted: rub_eye (Time: 0.0839s)
# Ảnh: 20250307_232312_245.jpg - True: natural, Predicted: rub_eye (Time: 0.0758s)
# Ảnh: 20250307_232312_246.jpg - True: natural, Predicted: rub_eye (Time: 0.0964s)
# Ảnh: 20250307_232312_247.jpg - True: natural, Predicted: rub_eye (Time: 0.0800s)
# Ảnh: 20250307_232312_248.jpg - True: natural, Predicted: rub_eye (Time: 0.0878s)
# Ảnh: 20250307_232312_250.jpg - True: natural, Predicted: rub_eye (Time: 0.0990s)
# Ảnh: 21.jpg - True: natural, Predicted: look_away (Time: 0.0926s)
# Ảnh: 22.jpg - True: natural, Predicted: look_away (Time: 0.0835s)
# Ảnh: 23.jpg - True: natural, Predicted: look_away (Time: 0.0841s)
# Ảnh: 24.jpg - True: natural, Predicted: look_away (Time: 0.0743s)
# Ảnh: 25.jpg - True: natural, Predicted: look_away (Time: 0.0747s)
# Ảnh: 26.jpg - True: natural, Predicted: look_away (Time: 0.0773s)
# Ảnh: 27.jpg - True: natural, Predicted: look_away (Time: 0.0701s)
# Ảnh: 28.jpg - True: natural, Predicted: look_away (Time: 0.0762s)
# Ảnh: 29.jpg - True: natural, Predicted: look_away (Time: 0.0756s)
# Ảnh: 30.jpg - True: natural, Predicted: look_away (Time: 0.0715s)
# Ảnh: 31.jpg - True: natural, Predicted: look_away (Time: 0.0733s)
# Ảnh: 32.jpg - True: natural, Predicted: look_away (Time: 0.0753s)
# Ảnh: 33.jpg - True: natural, Predicted: look_away (Time: 0.0889s)
# Ảnh: 34.jpg - True: natural, Predicted: look_away (Time: 0.0852s)
# Ảnh: 35.jpg - True: natural, Predicted: look_away (Time: 0.0823s)
# Ảnh: 36.jpg - True: natural, Predicted: look_away (Time: 0.0715s)
# Ảnh: 37.jpg - True: natural, Predicted: look_away (Time: 0.0724s)
# Ảnh: 38.jpg - True: natural, Predicted: look_away (Time: 0.1056s)
# Ảnh: 5.jpg - True: natural, Predicted: look_away (Time: 0.1012s)
# Ảnh: 6.jpg - True: natural, Predicted: look_away (Time: 0.0957s)
# Ảnh: 7.jpg - True: natural, Predicted: look_away (Time: 0.1255s)
# Ảnh: 8.jpg - True: natural, Predicted: look_away (Time: 0.1067s)
# Ảnh: 9.jpg - True: natural, Predicted: look_away (Time: 0.1124s)
# Ảnh: 20250307_232312_189.jpg - True: rub_eye, Predicted: rub_eye (Time: 0.1020s)
# Ảnh: WIN_20250522_21_47_36_Pro_005.jpg - True: rub_eye, Predicted: rub_eye (Time: 0.1173s)
# Ảnh: WIN_20250522_21_47_36_Pro_017.jpg - True: rub_eye, Predicted: look_away (Time: 0.1085s)
# Ảnh: WIN_20250522_21_47_36_Pro_020.jpg - True: rub_eye, Predicted: look_away (Time: 0.1108s)
# Ảnh: WIN_20250522_21_47_36_Pro_024.jpg - True: rub_eye, Predicted: rub_eye (Time: 0.1172s)
# Ảnh: 115.jpg - True: sleepy_eye, Predicted: look_away (Time: 0.1036s)
# Ảnh: 116.jpg - True: sleepy_eye, Predicted: look_away (Time: 0.0943s)
# Ảnh: 117.jpg - True: sleepy_eye, Predicted: look_away (Time: 0.1413s)
# Ảnh: 118.jpg - True: sleepy_eye, Predicted: look_away (Time: 0.1380s)
# Ảnh: 15.jpg - True: sleepy_eye, Predicted: look_away (Time: 0.1108s)
# Ảnh: 16.jpg - True: sleepy_eye, Predicted: look_away (Time: 0.0891s)
# Ảnh: 174.jpg - True: sleepy_eye, Predicted: look_away (Time: 0.1219s)
# Ảnh: 175.jpg - True: sleepy_eye, Predicted: look_away (Time: 0.1139s)
# Ảnh: 176.jpg - True: sleepy_eye, Predicted: look_away (Time: 0.1010s)
# Ảnh: 177.jpg - True: sleepy_eye, Predicted: look_away (Time: 0.1140s)
# Ảnh: 178.jpg - True: sleepy_eye, Predicted: look_away (Time: 0.1001s)
# Ảnh: 179.jpg - True: sleepy_eye, Predicted: look_away (Time: 0.1071s)
# Ảnh: 180.jpg - True: sleepy_eye, Predicted: look_away (Time: 0.1113s)
# Ảnh: 181.jpg - True: sleepy_eye, Predicted: look_away (Time: 0.1654s)
# Ảnh: 182.jpg - True: sleepy_eye, Predicted: look_away (Time: 0.1289s)
# Ảnh: 183.jpg - True: sleepy_eye, Predicted: look_away (Time: 0.1293s)
# Ảnh: 20250307_232312_242.jpg - True: sleepy_eye, Predicted: rub_eye (Time: 0.1096s)
# Ảnh: 20250321_221026_119.jpg - True: sleepy_eye, Predicted: look_away (Time: 0.0923s)
# Ảnh: 3459.jpg - True: sleepy_eye, Predicted: look_away (Time: 0.1527s)
# Ảnh: 3460.jpg - True: sleepy_eye, Predicted: look_away (Time: 0.0941s)
# Ảnh: 3461.jpg - True: sleepy_eye, Predicted: look_away (Time: 0.1208s)
# Ảnh: 3462.jpg - True: sleepy_eye, Predicted: look_away (Time: 0.1209s)
# Ảnh: 3463.jpg - True: sleepy_eye, Predicted: look_away (Time: 0.1058s)
# Ảnh: 3464.jpg - True: sleepy_eye, Predicted: look_away (Time: 0.0981s)
# Ảnh: 3465.jpg - True: sleepy_eye, Predicted: look_away (Time: 0.0969s)
# Ảnh: 3466.jpg - True: sleepy_eye, Predicted: look_away (Time: 0.1270s)
# Ảnh: 3467.jpg - True: sleepy_eye, Predicted: look_away (Time: 0.0958s)
# Ảnh: 3468.jpg - True: sleepy_eye, Predicted: look_away (Time: 0.1083s)
# Ảnh: 3469.jpg - True: sleepy_eye, Predicted: look_away (Time: 0.1330s)
# Ảnh: 3470.jpg - True: sleepy_eye, Predicted: look_away (Time: 0.1037s)
# Ảnh: 3471.jpg - True: sleepy_eye, Predicted: look_away (Time: 0.0923s)
# Ảnh: 3472.jpg - True: sleepy_eye, Predicted: look_away (Time: 0.1266s)
# Ảnh: 3473.jpg - True: sleepy_eye, Predicted: look_away (Time: 0.0921s)
# Ảnh: 3474.jpg - True: sleepy_eye, Predicted: look_away (Time: 0.1078s)
# Ảnh: 3475.jpg - True: sleepy_eye, Predicted: look_away (Time: 0.0877s)
# Ảnh: 3476.jpg - True: sleepy_eye, Predicted: look_away (Time: 0.0998s)
# Ảnh: 3477.jpg - True: sleepy_eye, Predicted: look_away (Time: 0.1083s)
# Ảnh: 3478.jpg - True: sleepy_eye, Predicted: look_away (Time: 0.1040s)
# Ảnh: 3479.jpg - True: sleepy_eye, Predicted: look_away (Time: 0.1117s)
# Ảnh: 3480.jpg - True: sleepy_eye, Predicted: look_away (Time: 0.0920s)
# Ảnh: 40.jpg - True: sleepy_eye, Predicted: look_away (Time: 0.1382s)
# Ảnh: 83.jpg - True: sleepy_eye, Predicted: look_away (Time: 0.1308s)
# Ảnh: WIN_20250522_21_47_36_Pro_098.jpg - True: sleepy_eye, Predicted: rub_eye (Time: 0.0885s)
# Ảnh: 1310.jpg - True: yawn, Predicted: look_away (Time: 0.0841s)
# Ảnh: 1314.jpg - True: yawn, Predicted: look_away (Time: 0.0899s)
# Ảnh: 1327.jpg - True: yawn, Predicted: look_away (Time: 0.1020s)
# Ảnh: 1347.jpg - True: yawn, Predicted: look_away (Time: 0.0905s)
# Ảnh: 3210.jpg - True: yawn, Predicted: look_away (Time: 0.0957s)
# Ảnh: 3218.jpg - True: yawn, Predicted: look_away (Time: 0.0829s)
# Ảnh: 3228.jpg - True: yawn, Predicted: look_away (Time: 0.0866s)
# Ảnh: 3710.jpg - True: yawn, Predicted: look_away (Time: 0.1132s)
# Ảnh: 3716.jpg - True: yawn, Predicted: look_away (Time: 0.1012s)
# Ảnh: 446.jpg - True: yawn, Predicted: look_away (Time: 0.0989s)
# Ảnh: 447.jpg - True: yawn, Predicted: look_away (Time: 0.1074s)
# Ảnh: 448.jpg - True: yawn, Predicted: look_away (Time: 0.0936s)
# Ảnh: 449.jpg - True: yawn, Predicted: look_away (Time: 0.0871s)
# Ảnh: 450.jpg - True: yawn, Predicted: look_away (Time: 0.0823s)
# Ảnh: 451.jpg - True: yawn, Predicted: rub_eye (Time: 0.0891s)
# Ảnh: 452.jpg - True: yawn, Predicted: look_away (Time: 0.0824s)
# Ảnh: 453.jpg - True: yawn, Predicted: rub_eye (Time: 0.0873s)
# Ảnh: 454.jpg - True: yawn, Predicted: look_away (Time: 0.0901s)
# Ảnh: 455.jpg - True: yawn, Predicted: look_away (Time: 0.0932s)
# Ảnh: 456.jpg - True: yawn, Predicted: look_away (Time: 0.0951s)
# Ảnh: 457.jpg - True: yawn, Predicted: rub_eye (Time: 0.1004s)
# Ảnh: 458.jpg - True: yawn, Predicted: rub_eye (Time: 0.0968s)
# Ảnh: 459.jpg - True: yawn, Predicted: look_away (Time: 0.0979s)
# Ảnh: 460.jpg - True: yawn, Predicted: look_away (Time: 0.1271s)
# Ảnh: 461.jpg - True: yawn, Predicted: look_away (Time: 0.1267s)
# Ảnh: 462.jpg - True: yawn, Predicted: look_away (Time: 0.1012s)
# Ảnh: 463.jpg - True: yawn, Predicted: look_away (Time: 0.1004s)
# Ảnh: 464.jpg - True: yawn, Predicted: look_away (Time: 0.0902s)
# Ảnh: 465.jpg - True: yawn, Predicted: look_away (Time: 0.0906s)
# Ảnh: 466.jpg - True: yawn, Predicted: look_away (Time: 0.0810s)
# Ảnh: 467.jpg - True: yawn, Predicted: look_away (Time: 0.0920s)
# Ảnh: 468.jpg - True: yawn, Predicted: look_away (Time: 0.0889s)
# Ảnh: 469.jpg - True: yawn, Predicted: look_away (Time: 0.0999s)
# Ảnh: 470.jpg - True: yawn, Predicted: look_away (Time: 0.1075s)
# Ảnh: 471.jpg - True: yawn, Predicted: look_away (Time: 0.0930s)
# Ảnh: 472.jpg - True: yawn, Predicted: look_away (Time: 0.1039s)
# Ảnh: 473.jpg - True: yawn, Predicted: look_away (Time: 0.1057s)
# Ảnh: 474.jpg - True: yawn, Predicted: look_away (Time: 0.0987s)
# Ảnh: 475.jpg - True: yawn, Predicted: look_away (Time: 0.1100s)
# Ảnh: 487.jpg - True: yawn, Predicted: look_away (Time: 0.0940s)
#
# --- KẾT QUẢ ĐÁNH GIÁ (CNN trên ảnh đã crop sẵn) ---
# Số lượng ảnh đã xử lý: 156
# Thời gian xử lý trung bình mỗi ảnh (Classification): 0.1037 giây
# Tổng thời gian xử lý: 16.1755 giây
# Accuracy (tổng thể): 0.2115
# F1 Score (Macro, trên các lớp chính ['look_away', 'natural', 'rub_eye', 'sleepy_eye', 'yawn']): 0.1256
# F1 Score (Weighted, trên các lớp chính ['look_away', 'natural', 'rub_eye', 'sleepy_eye', 'yawn']): 0.0770
#
# Confusion Matrix (Tổng thể):
#             look_away  natural  rub_eye  sleepy_eye  yawn
# look_away          30        0        0           0     0
# natural            30        0        8           0     0
# rub_eye             2        0        3           0     0
# sleepy_eye         41        0        2           0     0
# yawn               36        0        4           0     0
#
# Classification Report (trên các lớp ['look_away', 'natural', 'rub_eye', 'sleepy_eye', 'yawn']):
#               precision    recall  f1-score   support
#
#    look_away       0.22      1.00      0.36        30
#      natural       0.00      0.00      0.00        38
#      rub_eye       0.18      0.60      0.27         5
#   sleepy_eye       0.00      0.00      0.00        43
#         yawn       0.00      0.00      0.00        40
#
#     accuracy                           0.21       156
#    macro avg       0.08      0.32      0.13       156
# weighted avg       0.05      0.21      0.08       156
#
#
# Kết quả tóm tắt đã được lưu vào: cnn_precropped_evaluation_output_with_images1\evaluation_summary_mobilenet_precropped.txt
# Confusion matrix saved to cnn_precropped_evaluation_output_with_images1\confusion_matrix_mobilenet_precropped.png
# Confusion matrix saved to cnn_precropped_evaluation_output_with_images1\confusion_matrix_mobilenet_precropped_normalized.png
#
# Đã hoàn thành. Kết quả và ảnh đã xử lý được lưu trong thư mục 'cnn_precropped_evaluation_output_with_images1'.

# %% [markdown]
# ## Crop

# %%
import cv2
import mediapipe as mp
import os
from pathlib import Path

# --- CẤU HÌNH ---
INPUT_IMAGE_ROOT_DIR = "test"  # THAY THẾ: Thư mục gốc chứa các thư mục con (class) với ảnh
OUTPUT_CROPPED_ROOT_DIR = "output_cropped_faces"          # THAY THẾ: Thư mục gốc để lưu các khuôn mặt đã cắt
MIN_DETECTION_CONFIDENCE = 0.5                            # Ngưỡng tin cậy cho phát hiện khuôn mặt
SAVE_ORIGINAL_IF_NO_FACE = False                          # True để copy ảnh gốc nếu không tìm thấy khuôn mặt

# --- KHỞI TẠO MEDIAPIPE FACE DETECTION ---
mp_face_detection = mp.solutions.face_detection
# model_selection=0: cho khoảng cách gần (dưới 2m)
# model_selection=1: cho khoảng cách xa hơn (lên đến 5m)
face_detector = mp_face_detection.FaceDetection(
    model_selection=0, min_detection_confidence=MIN_DETECTION_CONFIDENCE
)

def crop_and_save_faces(image_path_obj: Path, output_class_dir: Path, face_detector_instance):
    """
    Đọc ảnh, phát hiện khuôn mặt, cắt và lưu chúng.
    Trả về số lượng khuôn mặt được phát hiện và lưu.
    """
    try:
        image = cv2.imread(str(image_path_obj))
        if image is None:
            print(f"Lỗi: Không thể đọc ảnh: {image_path_obj}")
            return 0
    except Exception as e:
        print(f"Lỗi khi đọc ảnh {image_path_obj}: {e}")
        return 0

    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    results = face_detector_instance.process(image_rgb)

    faces_saved_count = 0
    if results.detections:
        for i, detection in enumerate(results.detections):
            bboxC = detection.location_data.relative_bounding_box
            ih, iw, _ = image.shape
            
            # Kiểm tra xem bboxC có tồn tại không
            if not bboxC:
                print(f"Cảnh báo: Không có relative_bounding_box cho detection {i} trong {image_path_obj.name}")
                continue

            x, y, w, h = int(bboxC.xmin * iw), int(bboxC.ymin * ih), \
                           int(bboxC.width * iw), int(bboxC.height * ih)

            # Đảm bảo tọa độ nằm trong ảnh và kích thước hợp lệ
            x_start, y_start = max(0, x), max(0, y)
            x_end, y_end = min(iw, x + w), min(ih, y + h)

            if x_end > x_start and y_end > y_start: # Kiểm tra crop hợp lệ
                cropped_face = image[y_start:y_end, x_start:x_end]
                
                # Tạo tên file cho ảnh crop
                original_filename_stem = image_path_obj.stem
                cropped_filename = f"{original_filename_stem}{image_path_obj.suffix}"
                output_path = output_class_dir / cropped_filename
                
                try:
                    cv2.imwrite(str(output_path), cropped_face)
                    faces_saved_count += 1
                except Exception as e:
                    print(f"Lỗi khi lưu ảnh crop {output_path}: {e}")
            else:
                print(f"Cảnh báo: Kích thước crop không hợp lệ cho {image_path_obj.name}, face {i}. Bỏ qua.")
    
    elif SAVE_ORIGINAL_IF_NO_FACE:
        # Nếu không có khuôn mặt nào được phát hiện và tùy chọn được bật
        output_path = output_class_dir / image_path_obj.name
        try:
            cv2.imwrite(str(output_path), image)
            print(f"Không tìm thấy khuôn mặt trong {image_path_obj.name}. Đã lưu ảnh gốc vào {output_path}")
        except Exception as e:
            print(f"Lỗi khi lưu ảnh gốc {output_path}: {e}")
            
    return faces_saved_count

def main():
    input_root = Path(INPUT_IMAGE_ROOT_DIR)
    output_root = Path(OUTPUT_CROPPED_ROOT_DIR)

    if not input_root.is_dir():
        print(f"LỖI: Thư mục đầu vào '{input_root}' không tồn tại hoặc không phải là thư mục.")
        return

    output_root.mkdir(parents=True, exist_ok=True)
    print(f"Khuôn mặt đã cắt sẽ được lưu vào: {output_root.resolve()}")

    total_images_processed = 0
    total_faces_cropped = 0

    # Duyệt qua các thư mục con (class) trong thư mục gốc đầu vào
    for class_dir in input_root.iterdir():
        if class_dir.is_dir():
            current_class_name = class_dir.name
            print(f"\nĐang xử lý lớp: {current_class_name}")

            # Tạo thư mục con tương ứng trong thư mục output
            output_class_dir_path = output_root / current_class_name
            output_class_dir_path.mkdir(parents=True, exist_ok=True)

            images_in_class = 0
            faces_in_class = 0

            # Duyệt qua các file ảnh trong thư mục lớp hiện tại
            for image_file in class_dir.glob('*'): # Lấy tất cả file
                if image_file.suffix.lower() in ['.png', '.jpg', '.jpeg', '.bmp', '.tiff']:
                    images_in_class += 1
                    total_images_processed += 1
                    print(f"  Đang xử lý ảnh: {image_file.name}")
                    
                    num_saved = crop_and_save_faces(image_file, output_class_dir_path, face_detector)
                    faces_in_class += num_saved
                    total_faces_cropped += num_saved
            
            print(f"  Hoàn thành lớp {current_class_name}: {images_in_class} ảnh đã xử lý, {faces_in_class} khuôn mặt đã cắt.")

    print("\n--- TÓM TẮT ---")
    print(f"Tổng số ảnh đã xử lý: {total_images_processed}")
    print(f"Tổng số khuôn mặt đã cắt và lưu: {total_faces_cropped}")
    print(f"Đã hoàn thành. Kiểm tra thư mục '{output_root.resolve()}'.")

if __name__ == "__main__":
    # Ví dụ cách tạo cấu trúc thư mục giả để test:
    # Path("test_input_images/class_A").mkdir(parents=True, exist_ok=True)
    # Path("test_input_images/class_B").mkdir(parents=True, exist_ok=True)
    # # Sau đó, bạn copy một vài ảnh vào thư mục test_input_images/class_A và test_input_images/class_B
    # # Rồi đặt INPUT_IMAGE_ROOT_DIR = "test_input_images"
    
    # Cần đảm bảo thư viện được import
    if 'cv2' not in globals() or 'mp' not in globals():
        print("Lỗi: Thiếu thư viện OpenCV hoặc MediaPipe.")
        print("Vui lòng cài đặt: pip install opencv-python mediapipe")
    else:
        main()
# Out:
# Khuôn mặt đã cắt sẽ được lưu vào: D:\Documents\Ki_8\XLA\yolov11_full_v3\output_cropped_faces
#
# Đang xử lý lớp: look_away
#   Đang xử lý ảnh: 20250307_222838_031.jpg
#   Đang xử lý ảnh: 20250307_222838_032.jpg
#   Đang xử lý ảnh: 20250307_222838_033.jpg
#   Đang xử lý ảnh: 20250307_222838_034.jpg
#   Đang xử lý ảnh: 20250307_222838_035.jpg
#   Đang xử lý ảnh: 20250307_222838_036.jpg
#   Đang xử lý ảnh: 20250307_222838_037.jpg
#   Đang xử lý ảnh: 20250307_222838_039.jpg
#   Đang xử lý ảnh: 20250307_222838_040.jpg
#   Đang xử lý ảnh: 20250307_222838_041.jpg
#   Đang xử lý ảnh: 20250307_222838_042.jpg
#   Đang xử lý ảnh: 20250307_222838_043.jpg
#   Đang xử lý ảnh: 20250307_222838_044.jpg
#   Đang xử lý ảnh: 20250307_222838_045.jpg
#   Đang xử lý ảnh: 20250307_222838_047.jpg
#   Đang xử lý ảnh: 20250307_222838_048.jpg
#   Đang xử lý ảnh: 20250307_222838_049.jpg
#   Đang xử lý ảnh: 20250307_222838_050.jpg
#   Đang xử lý ảnh: 20250307_222838_051.jpg
#   Đang xử lý ảnh: 20250307_222838_052.jpg
#   Đang xử lý ảnh: 20250307_222838_053.jpg
#   Đang xử lý ảnh: 20250307_222838_054.jpg
#   Đang xử lý ảnh: 20250307_222838_055.jpg
#   Đang xử lý ảnh: 20250307_222838_056.jpg
#   Đang xử lý ảnh: 20250307_222838_057.jpg
#   Đang xử lý ảnh: 20250307_222838_058.jpg
#   Đang xử lý ảnh: 20250307_222838_059.jpg
#   Đang xử lý ảnh: 20250307_222838_060.jpg
#   Đang xử lý ảnh: 20250307_222838_061.jpg
#   Đang xử lý ảnh: 20250307_222838_062.jpg
#   Hoàn thành lớp look_away: 30 ảnh đã xử lý, 30 khuôn mặt đã cắt.
#
# Đang xử lý lớp: natural
#   Đang xử lý ảnh: 10.jpg
#   Đang xử lý ảnh: 11.jpg
#   Đang xử lý ảnh: 12.jpg
#   Đang xử lý ảnh: 13.jpg
#   Đang xử lý ảnh: 14.jpg
#   Đang xử lý ảnh: 19.jpg
#   Đang xử lý ảnh: 20.jpg
#   Đang xử lý ảnh: 20250307_232312_210.jpg
#   Đang xử lý ảnh: 20250307_232312_211.jpg
#   Đang xử lý ảnh: 20250307_232312_244.jpg
#   Đang xử lý ảnh: 20250307_232312_245.jpg
#   Đang xử lý ảnh: 20250307_232312_246.jpg
#   Đang xử lý ảnh: 20250307_232312_247.jpg
#   Đang xử lý ảnh: 20250307_232312_248.jpg
#   Đang xử lý ảnh: 20250307_232312_250.jpg
#   Đang xử lý ảnh: 21.jpg
#   Đang xử lý ảnh: 22.jpg
#   Đang xử lý ảnh: 23.jpg
#   Đang xử lý ảnh: 24.jpg
#   Đang xử lý ảnh: 25.jpg
#   Đang xử lý ảnh: 26.jpg
#   Đang xử lý ảnh: 27.jpg
#   Đang xử lý ảnh: 28.jpg
#   Đang xử lý ảnh: 29.jpg
#   Đang xử lý ảnh: 30.jpg
#   Đang xử lý ảnh: 31.jpg
#   Đang xử lý ảnh: 32.jpg
#   Đang xử lý ảnh: 33.jpg
#   Đang xử lý ảnh: 34.jpg
#   Đang xử lý ảnh: 35.jpg
#   Đang xử lý ảnh: 36.jpg
#   Đang xử lý ảnh: 37.jpg
#   Đang xử lý ảnh: 38.jpg
#   Đang xử lý ảnh: 5.jpg
#   Đang xử lý ảnh: 6.jpg
#   Đang xử lý ảnh: 7.jpg
#   Đang xử lý ảnh: 8.jpg
#   Đang xử lý ảnh: 9.jpg
#   Hoàn thành lớp natural: 38 ảnh đã xử lý, 38 khuôn mặt đã cắt.
#
# Đang xử lý lớp: rub_eye
#   Đang xử lý ảnh: 20250307_232312_189.jpg
#   Đang xử lý ảnh: WIN_20250522_21_47_36_Pro_005.jpg
#   Đang xử lý ảnh: WIN_20250522_21_47_36_Pro_017.jpg
#   Đang xử lý ảnh: WIN_20250522_21_47_36_Pro_020.jpg
#   Đang xử lý ảnh: WIN_20250522_21_47_36_Pro_024.jpg
#   Hoàn thành lớp rub_eye: 5 ảnh đã xử lý, 5 khuôn mặt đã cắt.
#
# Đang xử lý lớp: sleepy_eye
#   Đang xử lý ảnh: 115.jpg
#   Đang xử lý ảnh: 116.jpg
#   Đang xử lý ảnh: 117.jpg
#   Đang xử lý ảnh: 118.jpg
#   Đang xử lý ảnh: 15.jpg
#   Đang xử lý ảnh: 16.jpg
#   Đang xử lý ảnh: 174.jpg
#   Đang xử lý ảnh: 175.jpg
#   Đang xử lý ảnh: 176.jpg
#   Đang xử lý ảnh: 177.jpg
#   Đang xử lý ảnh: 178.jpg
#   Đang xử lý ảnh: 179.jpg
#   Đang xử lý ảnh: 180.jpg
#   Đang xử lý ảnh: 181.jpg
#   Đang xử lý ảnh: 182.jpg
#   Đang xử lý ảnh: 183.jpg
#   Đang xử lý ảnh: 20250307_232312_242.jpg
#   Đang xử lý ảnh: 20250321_221026_119.jpg
#   Đang xử lý ảnh: 3459.jpg
#   Đang xử lý ảnh: 3460.jpg
#   Đang xử lý ảnh: 3461.jpg
#   Đang xử lý ảnh: 3462.jpg
#   Đang xử lý ảnh: 3463.jpg
#   Đang xử lý ảnh: 3464.jpg
#   Đang xử lý ảnh: 3465.jpg
#   Đang xử lý ảnh: 3466.jpg
#   Đang xử lý ảnh: 3467.jpg
#   Đang xử lý ảnh: 3468.jpg
#   Đang xử lý ảnh: 3469.jpg
#   Đang xử lý ảnh: 3470.jpg
#   Đang xử lý ảnh: 3471.jpg
#   Đang xử lý ảnh: 3472.jpg
#   Đang xử lý ảnh: 3473.jpg
#   Đang xử lý ảnh: 3474.jpg
#   Đang xử lý ảnh: 3475.jpg
#   Đang xử lý ảnh: 3476.jpg
#   Đang xử lý ảnh: 3477.jpg
#   Đang xử lý ảnh: 3478.jpg
#   Đang xử lý ảnh: 3479.jpg
#   Đang xử lý ảnh: 3480.jpg
#   Đang xử lý ảnh: 40.jpg
#   Đang xử lý ảnh: 83.jpg
#   Đang xử lý ảnh: WIN_20250522_21_47_36_Pro_098.jpg
#   Hoàn thành lớp sleepy_eye: 43 ảnh đã xử lý, 43 khuôn mặt đã cắt.
#
# Đang xử lý lớp: yawn
#   Đang xử lý ảnh: 1310.jpg
#   Đang xử lý ảnh: 1314.jpg
#   Đang xử lý ảnh: 1327.jpg
#   Đang xử lý ảnh: 1347.jpg
#   Đang xử lý ảnh: 3210.jpg
#   Đang xử lý ảnh: 3218.jpg
#   Đang xử lý ảnh: 3228.jpg
#   Đang xử lý ảnh: 3710.jpg
#   Đang xử lý ảnh: 3716.jpg
#   Đang xử lý ảnh: 446.jpg
#   Đang xử lý ảnh: 447.jpg
#   Đang xử lý ảnh: 448.jpg
#   Đang xử lý ảnh: 449.jpg
#   Đang xử lý ảnh: 450.jpg
#   Đang xử lý ảnh: 451.jpg
#   Đang xử lý ảnh: 452.jpg
#   Đang xử lý ảnh: 453.jpg
#   Đang xử lý ảnh: 454.jpg
#   Đang xử lý ảnh: 455.jpg
#   Đang xử lý ảnh: 456.jpg
#   Đang xử lý ảnh: 457.jpg
#   Đang xử lý ảnh: 458.jpg
#   Đang xử lý ảnh: 459.jpg
#   Đang xử lý ảnh: 460.jpg
#   Đang xử lý ảnh: 461.jpg
#   Đang xử lý ảnh: 462.jpg
#   Đang xử lý ảnh: 463.jpg
#   Đang xử lý ảnh: 464.jpg
#   Đang xử lý ảnh: 465.jpg
#   Đang xử lý ảnh: 466.jpg
#   Đang xử lý ảnh: 467.jpg
#   Đang xử lý ảnh: 468.jpg
#   Đang xử lý ảnh: 469.jpg
#   Đang xử lý ảnh: 470.jpg
#   Đang xử lý ảnh: 471.jpg
#   Đang xử lý ảnh: 472.jpg
#   Đang xử lý ảnh: 473.jpg
#   Đang xử lý ảnh: 474.jpg
#   Đang xử lý ảnh: 475.jpg
#   Đang xử lý ảnh: 487.jpg
#   Hoàn thành lớp yawn: 40 ảnh đã xử lý, 40 khuôn mặt đã cắt.
#
# --- TÓM TẮT ---
# Tổng số ảnh đã xử lý: 156
# Tổng số khuôn mặt đã cắt và lưu: 156
# Đã hoàn thành. Kiểm tra thư mục 'D:\Documents\Ki_8\XLA\yolov11_full_v3\output_cropped_faces'.
